# %% [markdown]
# # Загрузка Pandas и очистка данных

# %%
import pandas as pd
import numpy as np
import re
# from collections import Counter
import json
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('main_task.csv')

# %%
df.sample(5)
# Out:
#       Restaurant_id    City  \
# 13960      id_13589  London
# 29646       id_3789  Prague
# 38496       id_2735  Berlin
# 24106       id_4691   Paris
# 18734       id_5561   Paris
#
#                                            Cuisine Style  Ranking  Rating  \
# 13960                                ['Indian', 'Asian']  13599.0     4.0
# 29646                              ['European', 'Czech']   3798.0     3.0
# 38496                                                NaN   2737.0     5.0
# 24106                    ['French', 'European', 'Grill']   4692.0     3.5
# 18734  ['French', 'European', 'Spanish', 'Vegetarian ...   5562.0     4.0
#
#       Price Range  Number of Reviews  \
# 13960    $$ - $$$               22.0
# 29646         NaN                2.0
# 38496         NaN                4.0
# 24106    $$ - $$$              187.0
# 18734    $$ - $$$               39.0
#
#                                                  Reviews  \
# 13960  [['Good quality Indian restaurant', 'Not what ...
# 29646                                           [[], []]
# 38496     [['Best ice cream in Berlin'], ['06/21/2017']]
# 24106  [['Brief Encounter', 'Great location after vis...
# 18734  [['Relaxed Cocktail Bar', '"In the Middle Some...
#
#                                                   URL_TA      ID_TA
# 13960  /Restaurant_Review-g186338-d2254178-Reviews-Su...   d2254178
# 29646  /Restaurant_Review-g274707-d7123278-Reviews-Ka...   d7123278
# 38496  /Restaurant_Review-g187323-d12403442-Reviews-V...  d12403442
# 24106  /Restaurant_Review-g187147-d1323767-Reviews-Le...   d1323767
# 18734  /Restaurant_Review-g187147-d6155926-Reviews-Ar...   d6155926

# %% [markdown]
# Первоначальная версия датасета состоит из десяти столбцов, содержащих следующую информацию:
#
# * Restaurant_id — идентификационный номер ресторана / сети ресторанов;
# * City — город, в котором находится ресторан;
# * Cuisine Style — кухня или кухни, к которым можно отнести блюда, предлагаемые в ресторане;
# * Ranking — место, которое занимает данный ресторан среди всех ресторанов своего города;
# * Rating — рейтинг ресторана по данным TripAdvisor (именно это значение должна будет предсказывать модель);
# * Price Range — диапазон цен в ресторане;
# * Number of Reviews — количество отзывов о ресторане;
# * Reviews — данные о двух отзывах, которые отображаются на сайте ресторана;
# * URL_TA — URL страницы ресторана на TripAdvosor;
# * ID_TA — идентификатор ресторана в базе данных TripAdvisor.

# %%
# Ваш код по очистке данных и генерации новых признаков
# При необходимости добавьте ячейки

# %%
df.info()

# %%
df[df.duplicated()]   # проверяем, есть ли дубли в данных

# %% [markdown]
# # Задания из модуля

# %%
# 4.1
df['Price Range'].value_counts()

# %%
# 4.2
df['City'].value_counts().count()

# %%
# 4.3
print(df['Cuisine Style'].value_counts())
print(type(df['Cuisine Style'][0]))

pat = re.compile('\'(.*?)\'')
# cuisine_styles = df['Cuisine Style'].apply(lambda x: ['default'] if pd.isnull(x) else pat.findall(x))
cuisine_styles = df['Cuisine Style'].dropna().apply(lambda x: pat.findall(x))
cuisine_styles.explode().value_counts(ascending=False)

# %%
# 4.4
def replacer(matches):
    """
    Defines how re.sub should format a string including special cases.
    """
    
#     След фиксы пока в виде костылей, возм исправлю позже
    text = re.sub('\\\\x7f', '', matches.group('texts'))   # удаляем один бинарный символ (срока ...)
    text = re.sub('\\\\', '', text)   # удаляем одиночный \ в слове "can\'t" (строка ...)
    text = re.sub('\sna', " 'nan", text)   # для строки 5315, содержащей nan
    text = re.sub('an,\s', "nan', ", text)   # то же для строки 22958, содержащей nan в начале
    
    text = re.sub('"', "'", text)   # для всех цитат и апострофов в отзывах заменяем " на ', тк json.loads не работает с "
    texts = re.sub('((\'|\"), (\'|\"))', '", "', text)
    dates = re.sub('((\'|\"), (\'|\"))', '", "', matches.group('dates'))
    
    return '[["' + texts + '"], ["' + dates + '"]]'


def parse_review(string, obj):
    """
    Converts strings of df['Reviews'] into json.loads digestiable format.
    """
    
    string = re.sub('(\[\[.)(?P<texts>.*?)(.\], \[.)(?P<dates>.*?)(.\]\])', replacer, string)
    lst = json.loads(string)   # парсим

    if obj == 'Reviews':
        return lst[0] or None
    else:
        return lst[1] or None


def compare_lengths(row):
    """
    Checks if parsed lists of according reviews and dates are of the same length.
    """
    
    if row['Review'] is not None:
        if len(row['Review']) != len(row['Review date']):
            display(row)
            print(len(row['Review']), len(row['Review date']))


reviews_df = pd.DataFrame(columns=['Review', 'Review date'])
reviews_df['Review'] = df['Reviews'].apply(parse_review, obj='Reviews')
reviews_df['Review date'] = df['Reviews'].apply(parse_review, obj='Dates')
display(reviews_df)

reviews_df.apply(compare_lengths, axis=1)
reviews_df = reviews_df.apply(pd.Series.explode)#.reset_index()
reviews_df['Review date'] = pd.to_datetime(reviews_df['Review date'])
display(reviews_df)
# Out:
#                                                   Review  \
# 0      [Good food at your doorstep, A good hotel rest...
# 1              [Unique cuisine, Delicious Nepalese food]
# 2               [Catch up with friends, Not exceptional]
# 3                                                   None
# 4      [Best place to try a Bavarian food, Nice build...
# ...                                                  ...
# 39995  [The real Italian experience!, Wonderful food,...
# 39996  [Parisian atmosphere, Bit pricey but interesti...
# 39997  [Good by swedish standards, A hidden jewel in ...
# 39998  [Underground restaurant, Oldest Restaurant in ...
# 39999                        [Average, Nice an informal]
#
#                     Review date
# 0      [12/31/2017, 11/20/2017]
# 1      [07/06/2017, 06/19/2016]
# 2      [01/08/2018, 01/06/2018]
# 3                          None
# 4      [11/18/2017, 02/19/2017]
# ...                         ...
# 39995  [12/16/2017, 11/12/2017]
# 39996  [12/21/2017, 12/12/2017]
# 39997  [11/03/2016, 04/12/2008]
# 39998  [07/11/2017, 06/18/2017]
# 39999  [01/31/2016, 07/04/2012]
#
# [40000 rows x 2 columns]
#                                               Review Review date
# 0                         Good food at your doorstep  2017-12-31
# 0                            A good hotel restaurant  2017-11-20
# 1                                     Unique cuisine  2017-07-06
# 1                            Delicious Nepalese food  2016-06-19
# 2                              Catch up with friends  2018-01-08
# ...                                              ...         ...
# 39997  A hidden jewel in the middle of Västertorp...  2008-04-12
# 39998                         Underground restaurant  2017-07-11
# 39998                    Oldest Restaurant in Warsaw  2017-06-18
# 39999                                        Average  2016-01-31
# 39999                               Nice an informal  2012-07-04
#
# [68973 rows x 2 columns]

# %%
# строки, на которых спотыкалось:
stumble1 = str([["Don't eat here if you have a train to catc...", 'Lunchtime drink'], ['10/11/2017', '07/03/2017']])
stumble2 = str([['"Best Local"', 'Perfect pitstop'], ['02/09/2017', '04/17/2015']])
stumble3 = str([['Lillian restaurant reviews', 'Greasy Spoon\x7f'], ['12/20/2017', '07/09/2017']])
stumble4 = str([['Sat night', 'Can\'t even explain.. "A" place.. A "100...'], ['10/22/2017', '05/11/2017']])
stumble5 = df.iloc[5315]['Reviews']   # 5315
stumble6 = df.iloc[22958]['Reviews']   # 22958


def replacer1(matches):
    text = re.sub('\\\\x7f', '', matches.group('texts'))   # удаляем один бинарный символ (срока ...)
    text = re.sub('\\\\', '', text)   # удаляем одиночный \ в слове "can\'t" (строка ...)
    text = re.sub('\sna', " 'nan", text)   # для строки 5315, содержащей nan в конце
    text = re.sub('an,\s', "nan', ", text)   # то же для строки 22958, содержащей nan в начале
    text = re.sub('"', "'", text)   # для всех цитат и апострофов в отзывах заменяем " на ', тк json.loads не работает с "
    texts = re.sub('((\'|\"), (\'|\"))', '", "', text)
    dates = re.sub('((\'|\"), (\'|\"))', '", "', matches.group('dates'))
    return '[["' + texts + '"], ["' + dates + '"]]'


# stumble3.encode('utf-8').replace(b'\x7f', '')
print(stumble3)
print(stumble3.replace(r'\x7f', ''))
print(stumble4.replace('\\', '\\\\'))

stumble5 = re.sub('(\[\[.)(?P<texts>.*?)(.\], \[.)(?P<dates>.*?)(.\]\])', replacer1, stumble5)
# lst1 = json.loads(stumble5)   # парсим
print(stumble5)

y = eval(stumble4)
type(y)

# %%
# 4.4
print(reviews_df['Review date'].max())
last = reviews_df['Review date'].max()
first = reviews_df['Review date'].min()
print(last, first)
print(last - first)

# %% [markdown]
# В ходе выполнения заданий из модуля выяснили, что столбцы "Cuisine Style", "Reviews" заполнены строками, выглядящими как списки, превратили их в списки, проверили корректность заполнения, для "Cuisine Style" посчитали число уникальных значений, собрали их в массив; "Reviews" разбили на отзывы и их даты, поставили в соответствие. Т.о. сделана часть работы по извлечению инсайтов.

# %% [markdown]
# # Извлекаем инсайты

# %% [markdown]
# <i>Сategorical parameters:</i> Restaurant_id, City, Cuisine Style, Reviews, URL_TA, ID_TA
#
# <i>Ordinal parameters:</i> Price Range
#
# <i>Numerical parameters:</i> Ranking, Rating, Number of Reviews

# %% [markdown]
# ## Categorical parameters

# %% [markdown]
# ### 1. Restaurant_id

# %%
print('Total input number: {}'.format(len(df['Restaurant_id'])))
print('Total amount of restaurants: {}'.format(df['Restaurant_id'].nunique()))
print('Most comon restaurants (over 10 inputs): ')
common_rests = df['Restaurant_id'].value_counts()
common_rests

# %%
# check if restaurants with the same id are located in one city (or it's the same restaurant)
for rest in common_rests.index:
#     print('Rest {}, number of inputs: {}, number of cities: {}'.format(rest,     # вывод слишком длинный, поэтому см ниже
#             common_rests[rest], df[df['Restaurant_id'] == rest]['City'].nunique()))
    if common_rests[rest] != df[df['Restaurant_id'] == rest]['City'].nunique():
        print('inequal')

# %% [markdown]
# **Вывод:** один и тот же ресторан в разных городах выступает под одним id (возможно, сети). Записи о ресторанах не повторяются, пропусков нет.

# %% [markdown]
# ### 2. City

# %%
df['City'].value_counts()

# %% [markdown]
# Города указаны должным образом, пропусков нет, необходимо сгенерировать dummy-переменные.

# %% [markdown]
# ### 3. Cuisine Style
#
# Cм задание 4.3.
#
# В этой колонке содержатся строки, визуально выглядящие как списки. Есть пропуски, попытаемся заполнить их ниже.

# %% [markdown]
# ### 4. Reviews
#
# См. задание 4.4.
#
# Также строки, выглядящие как списки, каждая содержит 2 "списка" - первый с отзывами, второй с их датами, по 0-2 отзыва в каждой ячейке. Разделим их и вынесем в отдельные колонки.
#
# Есть как настоящие пропуски, так и пустые списки. Поэтому после извлечения настоящих отзывов получится немало пропусков.

# %%
print(df['Reviews'][1], '\n', type(df['Reviews'][0]))
print(df['Reviews'][0])
print('Кол-во пропусков: {}'.format(df['Reviews'].isna().sum()))

# %%
df['Reviews_new'] = df['Reviews'].apply(parse_review, obj='Reviews')
df['Review_dates'] = df['Reviews'].apply(parse_review, obj='Dates')

# %%
def extract_item(cell):
    if cell and i < len(cell):
        return cell[i]
    else:
        return None


for i in range(2):
    col_name = 'Review ' + str(i + 1)
    df[col_name] = df['Reviews_new'].apply(extract_item)
    
    col_name_date = 'Date ' + str(i + 1)
    df[col_name_date] = pd.to_datetime(df['Review_dates'].apply(extract_item))


df.drop(['Reviews', 'Reviews_new', 'Review_dates'], axis=1, inplace=True)

# %%
# насколько полно заполнены отзывы и их даты:
df.info()

# %%
df.sample(3)

# %% [markdown]
# ### 5. URL_TA

# %%
df['URL_TA'].nunique()

# %% [markdown]
# Число уникальных записей на 20 меньше, чем общее число записей. Посмотрим на повторяющиеся.

# %%
df['URL_TA'].value_counts()

# %% [markdown]
# Видно, что в ссылке на ресторан на TripAdvisor "зашиты" названия и местонахождения (геолокации) ресторанов, а также какие-то численные данные с префиксами d и g. Эти признаки можно из ссылок извлечь, интерпретировать и использовать в дальнейшем. Например, по названию ресторана можно попробовать определить кухню, которую в нем предлагают. Геолокация вряд ли понадобится, т.к. колонка City у нас не содержит пропусков.
#
# Можно проверить, совпадают ли города в колонке City с городами в ссылке.
#
# Извлекаем признаки:

# %%
def find_pat(cell):
    match = pat.search(cell)
    return match.group(feature) if match else None


pat = re.compile('(?P<URL_g>g.*)-(?P<URL_d>d.+)-Reviews-(?P<Restaurant_title>.*)-(?P<Restaurant_geo>.*)\.')
re_groups = ['URL_g', 'URL_d', 'Restaurant_title', 'Restaurant_geo']


for feature in re_groups:
    df[feature] = df['URL_TA'].apply(find_pat)

# %%
df.sample(5)

# %%
# проверим те строки, где не был найден паттерн (regex не сработал):
subset = df[df['URL_g'].isna()]
display(subset)
for i in subset['URL_TA']:
    print(i)

# %%
# воспользуемся отдельным паттерном для этих строк:
inds = subset.index

pat1 = re.compile('(?P<URL_g>g.*)-(?P<URL_d>d.+)-Reviews-(?P<Restaurant_geo>.*)\.')
re_groups1 = ['URL_g', 'URL_d', 'Restaurant_geo']

for feature in re_groups1:
    df[feature][inds] = df['URL_TA'][inds].apply(lambda x: pat1.search(x).group(feature))

# %%
# проверим, все ли заполнилось:
df.info()

# %% [markdown]
# Теперь посмотрим, совпадают ли города в колонке City с городами, извлеченными из ссылок на рестораны в TripAdvisor. Заодно возьмем на рассмотрение те рестораны, где кухни отсутствовали:

# %%
df[df['Cuisine Style'].isna()].sample(5)

# %% [markdown]
# Гео, извлеченное из URL, содержит более развернутую информацию о местонахождении ресторана (район города, муниципальный округ и т.д.).

# %% [markdown]
# ### 5. URL_g

# %%
print(df['URL_g'].nunique())
df['URL_g'].value_counts()

# %%
print(df[df['URL_g'] == 'g186338'].shape)
df[df['URL_g'] == 'g186338'].sample(5)

# %% [markdown]
# Скорее всего, этот признак соответствует геолокации ресторана, т.е. совпадает с 'Restaurant geo' (не с 'City' - ранее видели, что всего городов 31, т.е. меньше, чем никальных значений 'URL_g').

# %%
print(df['Restaurant_geo'].nunique())
df['Restaurant_geo'].value_counts()

# %% [markdown]
# Не совсем - цифры различаются. Далее углубляться не будем, все равно колонка с городами не содержит пропусков - использовать URL_g незачем.

# %% [markdown]
# ### 6. URL_d

# %%
print(df['URL_d'].nunique())
df['URL_d'].value_counts()

# %% [markdown]
# Этот признак дублирует ID_TA (id ресторана на TripAdvisor-e) - см. ниже.

# %% [markdown]
# ### 4. ID_TA

# %%
df['ID_TA'].nunique()

# %%
v_c = df['ID_TA'].value_counts()
v_c

# %% [markdown]
# Опять число уникальных записей на 20 меньше, чем общее число записей - как в URL_TA. Скорее всего, повторения этих признаков перекрываются. Посмотрим, что общего у записей с одинаковым ID_TA.

# %%
rep_id_ta = v_c[v_c > 1].index
id_ta_subset = df[df['ID_TA'].isin(rep_id_ta)].sort_values('ID_TA')
display(id_ta_subset)
print('N of lines: {}'.format(id_ta_subset.shape[0]))

for col in id_ta_subset.columns:
    print('N unique in col {}: {}'.format(col, id_ta_subset[col].nunique()))

# %% [markdown]
# Все признаки одинаковы у пар ресторанов за исключением id, Ranking - они уникальны, однако очень близки. Возможно, произошел какой-то сбой и были внесены записи об одних и тех же ресторанах, только с небольшой разницей во времени.

# %%
# подумать, как можно заполнить пропуски в этой выборке

# %%
df.sample(5)

# %% [markdown]
# ## Ordinal parameters

# %%
print(df['Price Range'].isna().sum())
df['Price Range'].value_counts()

# %% [markdown]
# Колонка заполнена корректно, можно заменить на численные эквиваленты значений (см ниже в feature engineering).
#
# Имеются пропуски, ниже попытаемся заполнить на основе связей с другими признаками.

# %% [markdown]
# ## Numerical parameters

# %%
df[['Ranking', 'Rating']].corr()

# %%
df[['Ranking', 'Rating']].hist()

# %%
# sns.boxplot(data=df[['Ranking', 'Rating']], hue=df[['Ranking', 'Rating']].columns)
sns.boxplot(data=df['Ranking'])

# %% [markdown]
# # Заполнение пропусков
#
# Т.о. пропуски содержатся в колонках **'Cuisine Style', 'Price Range', 'Number of Reviews', 'Review n', 'Date n', 'Restaurant title'**.
#
# 1. **'Cuisine Style', 'Price Range', 'Number of Reviews'** можно попробовать заполнить на основе предполагаемых связей с другими признаками:
#
# -- 'Cuisine Style': ресторан может принадлежать к сети, в сетевых ресторанах, как правило, подают одну и ту же кухню - проверить можно по названию 'Restaurant_title';
#
# -- название ресторана 'Restaurant_title' может содержать или подразумевать кухню, которую в нем подают, например, ресторан с японским названием, расположенный в Италии, скорее всего предлагает японскую кухню;
#
# -- 'Price Range' может также зависеть от принадлежности ресторана к сети;
#
# -- его можно заполнить на основе распределения цен в ресторанах в каждом отдельном городе / подающих одну кухню / имеющих близкое число отзывов - в общем или в каждом отдельном городе / близкий 'Ranking'/'Rating' аналогично. Для этого скорее всего нужно формулировать гипотезы и статистически их проверять, затем заполнять пропуски на основе подтвержденных.
#
# -- 'Number of Reviews' - на основе его корреляции с 'Ranking' в каждом отдельном городе.
#
# 2. **'Review n', 'Date n', 'Restaurant title'** заполнить невозможно.
#
# <br>
# <i>А можно не строить гипотез и спарсить данные прямо с сайта. Так и сделаем.</i>

# %%
df_parsed = pd.read_csv('parsed_data_output3.csv', index_col=0)
df_parsed
# Out:
#       Restaurant_id                               Cuisine Style Price Range  \
# 19          id_2791                        ['Chinese', 'Asian']    $$ - $$$
# 32          id_1327                                         NaN         NaN
# 13          id_4637                                         NaN           $
# 33          id_2434                              ['Vietnamese']         NaN
# 37          id_5209          ['Chinese', 'Japanese', 'Seafood']    $$ - $$$
# ...             ...                                         ...         ...
# 39996       id_6340               ['French', 'Bar', 'European']    $$ - $$$
# 39995        id_499  ['Italian', 'Lombard', 'Northern-Italian']    $$ - $$$
# 39994       id_7074    ['French', 'Fast Food', 'Mediterranean']    $$ - $$$
# 39991       id_6655        ['French', 'Contemporary', 'Fusion']    $$ - $$$
# 39981        id_924                                         NaN         NaN
#
#        Number of Reviews
# 19                  18.0
# 32                   1.0
# 13                  11.0
# 33                   4.0
# 37                  74.0
# ...                  ...
# 39996               16.0
# 39995              292.0
# 39994               10.0
# 39991               64.0
# 39981                NaN
#
# [39050 rows x 4 columns]

# %%
df_parsed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39050 entries, 19 to 39981
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Restaurant_id      39050 non-null  object
#  1   Cuisine Style      31230 non-null  object
#  2   Price Range        28937 non-null  object
#  3   Number of Reviews  34995 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 1.5+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Restaurant_id      40000 non-null  object
#  1   City               40000 non-null  object
#  2   Cuisine Style      30717 non-null  object
#  3   Ranking            40000 non-null  float64
#  4   Rating             40000 non-null  float64
#  5   Price Range        26114 non-null  object
#  6   Number of Reviews  37457 non-null  float64
#  7   Reviews            40000 non-null  object
#  8   URL_TA             40000 non-null  object
#  9   ID_TA              40000 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 3.1+ MB

# %%
df_parsed['Restaurant_id'].nunique()
# Out:
# 11794

# %%
df['Restaurant_id'].nunique()
# Out:
# 11909

# %% [markdown]
# Id повторяются, поэтому придется выбирать, чем заполнять пропуски.

# %%
def fillna_with_parsed_data(column):
    """
    consider replacing by df.apply compatible function
    """
    
    for idx, row in df[df[column].isna()].iterrows():
        rest_id = row['Restaurant_id']
        parsed_values = df_parsed.loc[df_parsed['Restaurant_id'] == rest_id, column]
        if len(parsed_values) > 1 and parsed_values.notna().sum() > 0:   # не все NaN
            if column == 'Cuisine Style':
                df.loc[idx, column] = [parsed_values.loc[parsed_values.str.len().idxmax()]]
                # пока выбираем самую длинную строчку с кухнями
                # можно вместо этого выбирать самые встречающиеся кухни из полученного набора для данного id
            elif column == 'Price Range':
                df.loc[idx, column] = [parsed_values.value_counts().idxmax()]   # most common value
            else:
                df.loc[idx, column] = [parsed_values.median()]    # median of numbers of reviews
        elif len(parsed_values) == 0:
            df.loc[idx, column] = [np.nan]
        else:
            df.loc[idx, column] = [parsed_values.iloc[0]]    # either 1 or more values - first is NaN if all are NaN,
                                                             # or only non Nan value
    print(f'finished {col}')
            
            
for col in ['Cuisine Style', 'Price Range', 'Number of Reviews']:
    fillna_with_parsed_data(col)
# Out:
# finished Cuisine Style
# finished Price Range
# finished Number of Reviews

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Restaurant_id      40000 non-null  object
#  1   City               40000 non-null  object
#  2   Cuisine Style      38942 non-null  object
#  3   Ranking            40000 non-null  float64
#  4   Rating             40000 non-null  float64
#  5   Price Range        37999 non-null  object
#  6   Number of Reviews  39910 non-null  float64
#  7   Reviews            40000 non-null  object
#  8   URL_TA             40000 non-null  object
#  9   ID_TA              40000 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 3.1+ MB

# %% [markdown]
# Результат просто отличный, пропусков осталось не так много.

# %% [markdown]
# ### 1. Cuisine Style

# %%
# проверяем, много ли пропусков. Ранее мы видели, что id ресторана не зависит от принадлежности к сети, т.е. у одинаковых
# id могут быть совершенно разные кухни. Проверим зависимость от названия, извлеченного из url:
print('Число пропусков в кухнях: {}'.format(df['Cuisine Style'].isna().sum()))
print('Число уникальных названий ресторанов в строках с пропущенными кухнями: {}'.format(df[df['Cuisine Style'].isna()]
                                                                                         ['Restaurant_title'].nunique()))

# %%
df['Restaurant_title'].value_counts()

# %%
print(df[df['Restaurant_title'] == 'Burger_King'].shape)
df[df['Restaurant_title'] == 'Burger_King'].sample(5)

# %%
print(df[df['Restaurant_title'] == 'Hippopotamus'].shape)
df[df['Restaurant_title'] == 'Hippopotamus'].sample(5)

# %% [markdown]
# Т.о. имеются сети ресторанов с пропусками в кухнях => их можно легко заполнить.
#
# NB: Стили кухонь могут немного отличаться в зависимости от геолокации. Можно заполнять в зависимости от гео, однако не будем усложнять задачу и заполним наиболее популярными значениями из выборок по названиям ресторанов.

# %%
# функция очень долгая, необходимо оптимизировать
# заполняем пропуски кухонь в сетевых ресторанах

def fill_cuisine_na(row):
    """
    Fills in missing cuisine style for chain restaurants.
    """
    
    if pd.isnull(row['Cuisine Style']):
        title = row['Restaurant_title']
        if title:   # проверяем, нет ли пропуска в названии ресторана, у нас имеются 2 таких строки. Если пропуск - вернется None
            subset = df[df['Restaurant_title'] == title]['Cuisine Style']
            if subset.nunique() > 0:                    # если наборы кухонь разные
                return subset.value_counts().idxmax()   # возвращаем наиболее часто встречающееся значение
    else:
        return row['Cuisine Style']


cuisine_styles_filled = df.apply(fill_cuisine_na, axis=1)

# %%
cuisine_styles_filled.isna().sum()   # сократили на ~1000

# %%
# сначала преобразуем строки в списки
# pat = re.compile('\'(.*?)\'')
# df['Cuisine Style'] = df['Cuisine Style'].dropna().apply(lambda x: pat.findall(x))   # regex is more efficient that eval()

# %%
# заполняем пропуски кухонь на основе названий ресторанов:

# def cuisine_from_title(row):
#     title = ...
#     for word in df[]:
        
def split_title(title):
    if pd.isnull(title):
        return None
    else:
        splitted = title.split('_')
        splitted = list(filter(lambda x: len(x) > 2, splitted))
        return splitted

titles_words = df[df['Cuisine Style'].notna()]['Restaurant_title'].apply(split_title)
titles_of_na_cuisines = df[df['Cuisine Style'].isna()]['Restaurant_title'].apply(split_title)

# %%
titles_words

# %%
print(titles_of_na_cuisines.iloc[2])

cur_cuisines = []

for idx, title in np.ndenumerate(df[df['Cuisine Style'].notna()]['Restaurant_title'].dropna()):
    if any(word in title for word in titles_of_na_cuisines.iloc[2]):
        print(title)
        print(df.iloc[idx]['Cuisine Style'])
        cur_cuisines.append(df.iloc[idx]['Cuisine Style'])

# %%
df['Restaurant_title'][:10]

# %%
# на основе распределения кухонь по городам - последний и наименее точный метод:

def cuisine_distr_in_city(city):
    cuisines = df[df['Restaurant_geo'] == city]['Cuisine Style'].apply(lambda x: None if pd.isnull(x)
                                                        else re.findall('\'(.*?)\'', x)).explode().value_counts()
    print(city)
    print(cuisines.nlargest(3))
    
    fig, ax = plt.subplots(figsize=(8, 5))
    sns.barplot(x=cuisines.index, y=cuisines.values, data=cuisines, ax=ax)
    plt.show()


na_cuisine_geos = df[df['Cuisine Style'].isna()]['Restaurant_geo'].unique()   # города, в которых есть пропуски кухонь
# df[df['Restaurant_geo'] == cui_na_geos[0]]['Cuisine Style'].apply(lambda x: None if pd.isnull(x) else re.findall('\'(.*?)\'', x)).explode().value_counts().plot.bar()

for city in na_cuisine_geos[:10]:
    cuisine_distr_in_city(city)

# %%
df.sample(3)

# %%
df['Cuisine Style'] = cuisine_styles_filled

# %% [markdown]
# ### 2. URL_g
#
# Из url мы извлекли геолокацию ресторанов, проверим, есть ли пустоты в городах и можно ли их заполнить с помощью нового параметра.

# %%
df['URL_g'].value_counts()

# %%
df[df['City'].isna()].sort_values('URL_g')

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ## Categorical parameters

# %% [markdown]
# ### 1. Cuisine Style

# %%
# pd.concat([df[['Restaurant_id']], pd.get_dummies(df.explode('Cuisine Style')['Cuisine Style'], prefix='Cuisine', dummy_na=True)], axis=1, verify_integrity=True).drop_duplicates()

# %%
# option: explode by cuisines, get dummies, drop duplicates

def cuisine_dummies(rest):
#     print(rest, type(rest))
    if pd.isnull(rest):   # if cuisines in strings
#     if isinstance(rest, list) is False:   # if cuisines in lists
        return 0
    else:
        return int(cuisine in rest)     
    
    
pat = re.compile('\'(.*?)\'')
cuisine_styles = df['Cuisine Style'].dropna().apply(lambda x: pat.findall(x))
unique_cuisine_styles = np.sort(cuisine_styles.explode().unique())

for cuisine in unique_cuisine_styles:
    cuisine_prefixed = f'Cuisine_{cuisine}'
    df[cuisine_prefixed] = df['Cuisine Style'].apply(cuisine_dummies)

df['Cuisine_nan'] = df['Cuisine Style'].apply(lambda x: 1 if pd.isnull(x) else 0)   # if cuisines in strings
# df['Cuisine_nan'] = df['Cuisine Style'].apply(lambda x: 0 if isinstance(x, list) else 1)   # if cuisines in lists

df.sample(5)
# Out:
#       Restaurant_id    City  \
# 15858        id_710   Paris
# 5101         id_259  Oporto
# 27227       id_4072  Berlin
# 6966        id_1274  Geneva
# 4005        id_1764   Milan
#
#                                            Cuisine Style  Ranking  Rating  \
# 15858  ['Indian', 'Vegetarian Friendly', 'Vegan Optio...    711.0     4.5
# 5101                                        ['Wine Bar']    260.0     4.5
# 27227        ['Italian', 'Pizza', 'Vegetarian Friendly']   4074.0     5.0
# 6966             ['French', 'Mediterranean', 'European']   1280.0     3.0
# 4005                                         ['Italian']   1766.0     4.0
#
#       Price Range  Number of Reviews  \
# 15858    $$ - $$$              165.0
# 5101     $$ - $$$              110.0
# 27227           $                4.0
# 6966     $$ - $$$               21.0
# 4005     $$ - $$$              147.0
#
#                                                  Reviews  \
# 15858  [['Amazing food and service! Not too pricey e....
# 5101   [['comfortable', 'Feeling at home.'], ['11/15/...
# 27227  [['Time out time.', 'Great Restaurant And Bar ...
# 6966   [['Balances Italian in Lucerne Switzerland'], ...
# 4005   [['enjoyable', 'Not for the hungry'], ['05/31/...
#
#                                                   URL_TA     ID_TA  \
# 15858  /Restaurant_Review-g187147-d796860-Reviews-Les...   d796860
# 5101   /Restaurant_Review-g189180-d6419932-Reviews-Pr...  d6419932
# 27227  /Restaurant_Review-g187323-d5970756-Reviews-Co...  d5970756
# 6966   /Restaurant_Review-g188057-d1044859-Reviews-Ba...  d1044859
# 4005   /Restaurant_Review-g187849-d2362441-Reviews-Vi...  d2362441
#
#        Cuisine_Afghani  Cuisine_African  Cuisine_Albanian  Cuisine_Algerian  \
# 15858                0                0                 0                 0
# 5101                 0                0                 0                 0
# 27227                0                0                 0                 0
# 6966                 0                0                 0                 0
# 4005                 0                0                 0                 0
#
#        Cuisine_American  Cuisine_Arabic  Cuisine_Argentinean  \
# 15858                 0               0                    0
# 5101                  0               0                    0
# 27227                 0               0                    0
# 6966                  0               0                    0
# 4005                  0               0                    0
#
#        Cuisine_Armenian  Cuisine_Asian  Cuisine_Australian  Cuisine_Austrian  \
# 15858                 0              0                   0                 0
# 5101                  0              0                   0                 0
# 27227                 0              0                   0                 0
# 6966                  0              0                   0                 0
# 4005                  0              0                   0                 0
#
#        Cuisine_Azerbaijani  Cuisine_Bakeries  Cuisine_Balti  \
# 15858                    0                 0              0
# 5101                     0                 0              0
# 27227                    0                 0              0
# 6966                     0                 0              0
# 4005                     0                 0              0
#
#        Cuisine_Bangladeshi  Cuisine_Bar  Cuisine_Barbecue  Cuisine_Basque  \
# 15858                    0            0                 0               0
# 5101                     0            1                 0               0
# 27227                    0            0                 0               0
# 6966                     0            0                 0               0
# 4005                     0            0                 0               0
#
#        Cuisine_Beer restaurants  Cuisine_Beijing Specialties  Cuisine_Belgian  \
# 15858                         0                            0                0
# 5101                          0                            0                0
# 27227                         0                            0                0
# 6966                          0                            0                0
# 4005                          0                            0                0
#
#        Cuisine_Brazilian  Cuisine_Brew Pub  Cuisine_British  Cuisine_Burmese  \
# 15858                  0                 0                0                0
# 5101                   0                 0                0                0
# 27227                  0                 0                0                0
# 6966                   0                 0                0                0
# 4005                   0                 0                0                0
#
#        Cuisine_Cafe  Cuisine_Cajun & Creole  Cuisine_Cambodian  \
# 15858             0                       0                  0
# 5101              0                       0                  0
# 27227             0                       0                  0
# 6966              0                       0                  0
# 4005              0                       0                  0
#
#        Cuisine_Campania  Cuisine_Canadian  Cuisine_Cantonese  \
# 15858                 0                 0                  0
# 5101                  0                 0                  0
# 27227                 0                 0                  0
# 6966                  0                 0                  0
# 4005                  0                 0                  0
#
#        Cuisine_Caribbean  Cuisine_Catalan  Cuisine_Caucasian  \
# 15858                  0                0                  0
# 5101                   0                0                  0
# 27227                  0                0                  0
# 6966                   0                0                  0
# 4005                   0                0                  0
#
#        Cuisine_Central American  Cuisine_Central Asian  \
# 15858                         0                      0
# 5101                          0                      0
# 27227                         0                      0
# 6966                          0                      0
# 4005                          0                      0
#
#        Cuisine_Central European  Cuisine_Central-Italian  Cuisine_Chilean  \
# 15858                         0                        0                0
# 5101                          0                        0                0
# 27227                         0                        0                0
# 6966                          0                        0                0
# 4005                          0                        0                0
#
#        Cuisine_Chinese  Cuisine_Colombian  Cuisine_Contemporary  \
# 15858                0                  0                     0
# 5101                 0                  0                     0
# 27227                0                  0                     0
# 6966                 0                  0                     0
# 4005                 0                  0                     0
#
#        Cuisine_Croatian  Cuisine_Cuban  Cuisine_Czech  Cuisine_Danish  \
# 15858                 0              0              0               0
# 5101                  0              0              0               0
# 27227                 0              0              0               0
# 6966                  0              0              0               0
# 4005                  0              0              0               0
#
#        Cuisine_Deli  Cuisine_Delicatessen  Cuisine_Dessert  \
# 15858             0                     0                0
# 5101              0                     0                0
# 27227             0                     0                0
# 6966              0                     0                0
# 4005              0                     0                0
#
#        Cuisine_Dine With a Local Chef  Cuisine_Diner  Cuisine_Dining bars  \
# 15858                               0              0                    0
# 5101                                0              0                    0
# 27227                               0              0                    0
# 6966                                0              0                    0
# 4005                                0              0                    0
#
#        Cuisine_Dutch  Cuisine_Eastern European  Cuisine_Ecuadorean  \
# 15858              0                         0                   0
# 5101               0                         0                   0
# 27227              0                         0                   0
# 6966               0                         0                   0
# 4005               0                         0                   0
#
#        Cuisine_Egyptian  Cuisine_Ethiopian  Cuisine_European  \
# 15858                 0                  0                 0
# 5101                  0                  0                 0
# 27227                 0                  0                 0
# 6966                  0                  0                 1
# 4005                  0                  0                 0
#
#        Cuisine_Fast Food  Cuisine_Filipino  Cuisine_French  Cuisine_Fujian  \
# 15858                  0                 0               0               0
# 5101                   0                 0               0               0
# 27227                  0                 0               0               0
# 6966                   0                 0               1               0
# 4005                   0                 0               0               0
#
#        Cuisine_Fusion  Cuisine_Gastropub  Cuisine_Georgian  Cuisine_German  \
# 15858               0                  0                 0               0
# 5101                0                  0                 0               0
# 27227               0                  0                 0               0
# 6966                0                  0                 0               0
# 4005                0                  0                 0               0
#
#        Cuisine_Gluten Free Options  Cuisine_Greek  Cuisine_Grill  \
# 15858                            0              0              0
# 5101                             0              0              0
# 27227                            0              0              0
# 6966                             0              0              0
# 4005                             0              0              0
#
#        Cuisine_Halal  Cuisine_Hawaiian  Cuisine_Healthy  Cuisine_Hong Kong  \
# 15858              0                 0                0                  0
# 5101               0                 0                0                  0
# 27227              0                 0                0                  0
# 6966               0                 0                0                  0
# 4005               0                 0                0                  0
#
#        Cuisine_Hungarian  Cuisine_Imperial Chinese  Cuisine_Indian  \
# 15858                  0                         0               1
# 5101                   0                         0               0
# 27227                  0                         0               0
# 6966                   0                         0               0
# 4005                   0                         0               0
#
#        Cuisine_Indonesian  Cuisine_International  Cuisine_Irish  \
# 15858                   0                      0              0
# 5101                    0                      0              0
# 27227                   0                      0              0
# 6966                    0                      0              0
# 4005                    0                      0              0
#
#        Cuisine_Israeli  Cuisine_Italian  Cuisine_Jamaican  Cuisine_Japanese  \
# 15858                0                0                 0                 0
# 5101                 0                0                 0                 0
# 27227                0                1                 0                 0
# 6966                 0                0                 0                 0
# 4005                 0                1                 0                 0
#
#        Cuisine_Japanese Fusion  Cuisine_Korean  Cuisine_Kosher  Cuisine_Latin  \
# 15858                        0               0               0              0
# 5101                         0               0               0              0
# 27227                        0               0               0              0
# 6966                         0               0               0              0
# 4005                         0               0               0              0
#
#        Cuisine_Latvian  Cuisine_Lazio  Cuisine_Lebanese  Cuisine_Lombard  \
# 15858                0              0                 0                0
# 5101                 0              0                 0                0
# 27227                0              0                 0                0
# 6966                 0              0                 0                0
# 4005                 0              0                 0                0
#
#        Cuisine_Malaysian  Cuisine_Mediterranean  Cuisine_Mexican  \
# 15858                  0                      0                0
# 5101                   0                      0                0
# 27227                  0                      0                0
# 6966                   0                      1                0
# 4005                   0                      0                0
#
#        Cuisine_Middle Eastern  Cuisine_Minority Chinese  Cuisine_Mongolian  \
# 15858                       0                         0                  0
# 5101                        0                         0                  0
# 27227                       0                         0                  0
# 6966                        0                         0                  0
# 4005                        0                         0                  0
#
#        Cuisine_Moroccan  Cuisine_Native American  Cuisine_Neapolitan  \
# 15858                 0                        0                   0
# 5101                  0                        0                   0
# 27227                 0                        0                   0
# 6966                  0                        0                   0
# 4005                  0                        0                   0
#
#        Cuisine_Nepali  Cuisine_New Zealand  Cuisine_NorthEastern Chinese  \
# 15858               0                    0                             0
# 5101                0                    0                             0
# 27227               0                    0                             0
# 6966                0                    0                             0
# 4005                0                    0                             0
#
#        Cuisine_NorthWestern Chinese  Cuisine_Northern-Italian  \
# 15858                             0                         0
# 5101                              0                         0
# 27227                             0                         0
# 6966                              0                         0
# 4005                              0                         0
#
#        Cuisine_Norwegian  Cuisine_Pakistani  Cuisine_Persian  \
# 15858                  0                  0                0
# 5101                   0                  0                0
# 27227                  0                  0                0
# 6966                   0                  0                0
# 4005                   0                  0                0
#
#        Cuisine_Peruvian  Cuisine_Pizza  Cuisine_Polish  Cuisine_Polynesian  \
# 15858                 0              0               0                   0
# 5101                  0              0               0                   0
# 27227                 0              1               0                   0
# 6966                  0              0               0                   0
# 4005                  0              0               0                   0
#
#        Cuisine_Portuguese  Cuisine_Pub  Cuisine_Quick Bites  Cuisine_Romana  \
# 15858                   0            0                    0               0
# 5101                    0            0                    0               0
# 27227                   0            0                    0               0
# 6966                    0            0                    0               0
# 4005                    0            0                    0               0
#
#        Cuisine_Romanian  Cuisine_Russian  Cuisine_Salvadoran  \
# 15858                 0                0                   0
# 5101                  0                0                   0
# 27227                 0                0                   0
# 6966                  0                0                   0
# 4005                  0                0                   0
#
#        Cuisine_Sardinian  Cuisine_Scandinavian  Cuisine_Scottish  \
# 15858                  0                     0                 0
# 5101                   0                     0                 0
# 27227                  0                     0                 0
# 6966                   0                     0                 0
# 4005                   0                     0                 0
#
#        Cuisine_Seafood  Cuisine_Shanghai  Cuisine_Sicilian  \
# 15858                0                 0                 0
# 5101                 0                 0                 0
# 27227                0                 0                 0
# 6966                 0                 0                 0
# 4005                 0                 0                 0
#
#        Cuisine_Singaporean  Cuisine_Slovenian  Cuisine_Soups  \
# 15858                    0                  0              0
# 5101                     0                  0              0
# 27227                    0                  0              0
# 6966                     0                  0              0
# 4005                     0                  0              0
#
#        Cuisine_South American  Cuisine_Southern-Italian  Cuisine_Southwestern  \
# 15858                       0                         0                     0
# 5101                        0                         0                     0
# 27227                       0                         0                     0
# 6966                        0                         0                     0
# 4005                        0                         0                     0
#
#        Cuisine_Spanish  Cuisine_Specialty Food Market  Cuisine_Sri Lankan  \
# 15858                0                              0                   0
# 5101                 0                              0                   0
# 27227                0                              0                   0
# 6966                 0                              0                   0
# 4005                 0                              0                   0
#
#        Cuisine_Steakhouse  Cuisine_Street Food  Cuisine_Sushi  \
# 15858                   0                    0              0
# 5101                    0                    0              0
# 27227                   0                    0              0
# 6966                    0                    0              0
# 4005                    0                    0              0
#
#        Cuisine_Swedish  Cuisine_Swiss  Cuisine_Szechuan  Cuisine_Taiwanese  \
# 15858                0              0                 0                  0
# 5101                 0              0                 0                  0
# 27227                0              0                 0                  0
# 6966                 0              0                 0                  0
# 4005                 0              0                 0                  0
#
#        Cuisine_Thai  Cuisine_Tibetan  Cuisine_Tunisian  Cuisine_Turkish  \
# 15858             0                0                 0                0
# 5101              0                0                 0                0
# 27227             0                0                 0                0
# 6966              0                0                 0                0
# 4005              0                0                 0                0
#
#        Cuisine_Ukrainian  Cuisine_Uzbek  Cuisine_Vegan Options  \
# 15858                  0              0                      1
# 5101                   0              0                      0
# 27227                  0              0                      0
# 6966                   0              0                      0
# 4005                   0              0                      0
#
#        Cuisine_Vegetarian Friendly  Cuisine_Venezuelan  Cuisine_Vietnamese  \
# 15858                            1                   0                   0
# 5101                             0                   0                   0
# 27227                            1                   0                   0
# 6966                             0                   0                   0
# 4005                             0                   0                   0
#
#        Cuisine_Welsh  Cuisine_Wine Bar  Cuisine_Xinjiang  Cuisine_Yunnan  \
# 15858              0                 0                 0               0
# 5101               0                 1                 0               0
# 27227              0                 0                 0               0
# 6966               0                 0                 0               0
# 4005               0                 0                 0               0
#
#        Cuisine_nan
# 15858            0
# 5101             0
# 27227            0
# 6966             0
# 4005             0

# %%
# from stackoverflow:
# https://stackoverflow.com/questions/29034928/pandas-convert-a-column-of-list-to-dummies
# pd.get_dummies(df['Cuisine Style'].apply(pd.Series).stack(), dummy_na=True).sum(level=0)

# %% [markdown]
# ### 2. City

# %%
df = pd.concat([df, pd.get_dummies(df['City'], prefix='City', dummy_na=True)], axis=1, verify_integrity=True)

# Restaurant_geo is more precise, try this:
# df = pd.concat([df, pd.get_dummies(df['Restaurant_geo'], prefix='Restaurant_geo', dummy_na=True)], axis=1, verify_integrity=True)

df.sample(5)
# Out:
#       Restaurant_id    City                                     Cuisine Style  \
# 33004       id_1638  Athens                                         ['Greek']
# 38713       id_1369  Athens                ['Bar', 'Cafe', 'Pub', 'Wine Bar']
# 25929       id_6596  London        ['Cafe', 'British', 'Vegetarian Friendly']
# 846         id_1767   Milan  ['Japanese', 'Brazilian', 'Vegetarian Friendly']
# 14348       id_7486  London                                   ['New Zealand']
#
#        Ranking  Rating Price Range  Number of Reviews  \
# 33004   1640.0     3.5           $               19.0
# 38713   1371.0     4.5           $                3.0
# 25929   6605.0     4.0           $               69.0
# 846     1769.0     4.0    $$ - $$$               25.0
# 14348   7495.0     4.5           $               11.0
#
#                                                  Reviews  \
# 33004  [['Απαραδεκτο', "Don't accept credit cards"], ...
# 38713  [['Amazing Bistro in the heart of Athens!'], [...
# 25929  [['Great breakfast, great family get-together'...
# 846    [['Evening drink before moving on'], ['10/21/2...
# 14348  [['Great coffee. pleasant place,interesting m....
#
#                                                   URL_TA      ID_TA  \
# 33004  /Restaurant_Review-g189400-d10390287-Reviews-S...  d10390287
# 38713  /Restaurant_Review-g189400-d11737612-Reviews-M...  d11737612
# 25929  /Restaurant_Review-g186338-d949288-Reviews-Tur...    d949288
# 846    /Restaurant_Review-g187849-d12927216-Reviews-C...  d12927216
# 14348  /Restaurant_Review-g186338-d8722473-Reviews-Ki...   d8722473
#
#        Cuisine_Afghani  Cuisine_African  Cuisine_Albanian  Cuisine_Algerian  \
# 33004                0                0                 0                 0
# 38713                0                0                 0                 0
# 25929                0                0                 0                 0
# 846                  0                0                 0                 0
# 14348                0                0                 0                 0
#
#        Cuisine_American  Cuisine_Arabic  Cuisine_Argentinean  \
# 33004                 0               0                    0
# 38713                 0               0                    0
# 25929                 0               0                    0
# 846                   0               0                    0
# 14348                 0               0                    0
#
#        Cuisine_Armenian  Cuisine_Asian  Cuisine_Australian  Cuisine_Austrian  \
# 33004                 0              0                   0                 0
# 38713                 0              0                   0                 0
# 25929                 0              0                   0                 0
# 846                   0              0                   0                 0
# 14348                 0              0                   0                 0
#
#        Cuisine_Azerbaijani  Cuisine_Bakeries  Cuisine_Balti  \
# 33004                    0                 0              0
# 38713                    0                 0              0
# 25929                    0                 0              0
# 846                      0                 0              0
# 14348                    0                 0              0
#
#        Cuisine_Bangladeshi  Cuisine_Bar  Cuisine_Barbecue  Cuisine_Basque  \
# 33004                    0            0                 0               0
# 38713                    0            1                 0               0
# 25929                    0            0                 0               0
# 846                      0            0                 0               0
# 14348                    0            0                 0               0
#
#        Cuisine_Beer restaurants  Cuisine_Beijing Specialties  Cuisine_Belgian  \
# 33004                         0                            0                0
# 38713                         0                            0                0
# 25929                         0                            0                0
# 846                           0                            0                0
# 14348                         0                            0                0
#
#        Cuisine_Brazilian  Cuisine_Brew Pub  Cuisine_British  Cuisine_Burmese  \
# 33004                  0                 0                0                0
# 38713                  0                 0                0                0
# 25929                  0                 0                1                0
# 846                    1                 0                0                0
# 14348                  0                 0                0                0
#
#        Cuisine_Cafe  Cuisine_Cajun & Creole  Cuisine_Cambodian  \
# 33004             0                       0                  0
# 38713             1                       0                  0
# 25929             1                       0                  0
# 846               0                       0                  0
# 14348             0                       0                  0
#
#        Cuisine_Campania  Cuisine_Canadian  Cuisine_Cantonese  \
# 33004                 0                 0                  0
# 38713                 0                 0                  0
# 25929                 0                 0                  0
# 846                   0                 0                  0
# 14348                 0                 0                  0
#
#        Cuisine_Caribbean  Cuisine_Catalan  Cuisine_Caucasian  \
# 33004                  0                0                  0
# 38713                  0                0                  0
# 25929                  0                0                  0
# 846                    0                0                  0
# 14348                  0                0                  0
#
#        Cuisine_Central American  Cuisine_Central Asian  \
# 33004                         0                      0
# 38713                         0                      0
# 25929                         0                      0
# 846                           0                      0
# 14348                         0                      0
#
#        Cuisine_Central European  Cuisine_Central-Italian  Cuisine_Chilean  \
# 33004                         0                        0                0
# 38713                         0                        0                0
# 25929                         0                        0                0
# 846                           0                        0                0
# 14348                         0                        0                0
#
#        Cuisine_Chinese  Cuisine_Colombian  Cuisine_Contemporary  \
# 33004                0                  0                     0
# 38713                0                  0                     0
# 25929                0                  0                     0
# 846                  0                  0                     0
# 14348                0                  0                     0
#
#        Cuisine_Croatian  Cuisine_Cuban  Cuisine_Czech  Cuisine_Danish  \
# 33004                 0              0              0               0
# 38713                 0              0              0               0
# 25929                 0              0              0               0
# 846                   0              0              0               0
# 14348                 0              0              0               0
#
#        Cuisine_Deli  Cuisine_Delicatessen  Cuisine_Dessert  \
# 33004             0                     0                0
# 38713             0                     0                0
# 25929             0                     0                0
# 846               0                     0                0
# 14348             0                     0                0
#
#        Cuisine_Dine With a Local Chef  Cuisine_Diner  Cuisine_Dining bars  \
# 33004                               0              0                    0
# 38713                               0              0                    0
# 25929                               0              0                    0
# 846                                 0              0                    0
# 14348                               0              0                    0
#
#        Cuisine_Dutch  Cuisine_Eastern European  Cuisine_Ecuadorean  \
# 33004              0                         0                   0
# 38713              0                         0                   0
# 25929              0                         0                   0
# 846                0                         0                   0
# 14348              0                         0                   0
#
#        Cuisine_Egyptian  Cuisine_Ethiopian  Cuisine_European  \
# 33004                 0                  0                 0
# 38713                 0                  0                 0
# 25929                 0                  0                 0
# 846                   0                  0                 0
# 14348                 0                  0                 0
#
#        Cuisine_Fast Food  Cuisine_Filipino  Cuisine_French  Cuisine_Fujian  \
# 33004                  0                 0               0               0
# 38713                  0                 0               0               0
# 25929                  0                 0               0               0
# 846                    0                 0               0               0
# 14348                  0                 0               0               0
#
#        Cuisine_Fusion  Cuisine_Gastropub  Cuisine_Georgian  Cuisine_German  \
# 33004               0                  0                 0               0
# 38713               0                  0                 0               0
# 25929               0                  0                 0               0
# 846                 0                  0                 0               0
# 14348               0                  0                 0               0
#
#        Cuisine_Gluten Free Options  Cuisine_Greek  Cuisine_Grill  \
# 33004                            0              1              0
# 38713                            0              0              0
# 25929                            0              0              0
# 846                              0              0              0
# 14348                            0              0              0
#
#        Cuisine_Halal  Cuisine_Hawaiian  Cuisine_Healthy  Cuisine_Hong Kong  \
# 33004              0                 0                0                  0
# 38713              0                 0                0                  0
# 25929              0                 0                0                  0
# 846                0                 0                0                  0
# 14348              0                 0                0                  0
#
#        Cuisine_Hungarian  Cuisine_Imperial Chinese  Cuisine_Indian  \
# 33004                  0                         0               0
# 38713                  0                         0               0
# 25929                  0                         0               0
# 846                    0                         0               0
# 14348                  0                         0               0
#
#        Cuisine_Indonesian  Cuisine_International  Cuisine_Irish  \
# 33004                   0                      0              0
# 38713                   0                      0              0
# 25929                   0                      0              0
# 846                     0                      0              0
# 14348                   0                      0              0
#
#        Cuisine_Israeli  Cuisine_Italian  Cuisine_Jamaican  Cuisine_Japanese  \
# 33004                0                0                 0                 0
# 38713                0                0                 0                 0
# 25929                0                0                 0                 0
# 846                  0                0                 0                 1
# 14348                0                0                 0                 0
#
#        Cuisine_Japanese Fusion  Cuisine_Korean  Cuisine_Kosher  Cuisine_Latin  \
# 33004                        0               0               0              0
# 38713                        0               0               0              0
# 25929                        0               0               0              0
# 846                          0               0               0              0
# 14348                        0               0               0              0
#
#        Cuisine_Latvian  Cuisine_Lazio  Cuisine_Lebanese  Cuisine_Lombard  \
# 33004                0              0                 0                0
# 38713                0              0                 0                0
# 25929                0              0                 0                0
# 846                  0              0                 0                0
# 14348                0              0                 0                0
#
#        Cuisine_Malaysian  Cuisine_Mediterranean  Cuisine_Mexican  \
# 33004                  0                      0                0
# 38713                  0                      0                0
# 25929                  0                      0                0
# 846                    0                      0                0
# 14348                  0                      0                0
#
#        Cuisine_Middle Eastern  Cuisine_Minority Chinese  Cuisine_Mongolian  \
# 33004                       0                         0                  0
# 38713                       0                         0                  0
# 25929                       0                         0                  0
# 846                         0                         0                  0
# 14348                       0                         0                  0
#
#        Cuisine_Moroccan  Cuisine_Native American  Cuisine_Neapolitan  \
# 33004                 0                        0                   0
# 38713                 0                        0                   0
# 25929                 0                        0                   0
# 846                   0                        0                   0
# 14348                 0                        0                   0
#
#        Cuisine_Nepali  Cuisine_New Zealand  Cuisine_NorthEastern Chinese  \
# 33004               0                    0                             0
# 38713               0                    0                             0
# 25929               0                    0                             0
# 846                 0                    0                             0
# 14348               0                    1                             0
#
#        Cuisine_NorthWestern Chinese  Cuisine_Northern-Italian  \
# 33004                             0                         0
# 38713                             0                         0
# 25929                             0                         0
# 846                               0                         0
# 14348                             0                         0
#
#        Cuisine_Norwegian  Cuisine_Pakistani  Cuisine_Persian  \
# 33004                  0                  0                0
# 38713                  0                  0                0
# 25929                  0                  0                0
# 846                    0                  0                0
# 14348                  0                  0                0
#
#        Cuisine_Peruvian  Cuisine_Pizza  Cuisine_Polish  Cuisine_Polynesian  \
# 33004                 0              0               0                   0
# 38713                 0              0               0                   0
# 25929                 0              0               0                   0
# 846                   0              0               0                   0
# 14348                 0              0               0                   0
#
#        Cuisine_Portuguese  Cuisine_Pub  Cuisine_Quick Bites  Cuisine_Romana  \
# 33004                   0            0                    0               0
# 38713                   0            1                    0               0
# 25929                   0            0                    0               0
# 846                     0            0                    0               0
# 14348                   0            0                    0               0
#
#        Cuisine_Romanian  Cuisine_Russian  Cuisine_Salvadoran  \
# 33004                 0                0                   0
# 38713                 0                0                   0
# 25929                 0                0                   0
# 846                   0                0                   0
# 14348                 0                0                   0
#
#        Cuisine_Sardinian  Cuisine_Scandinavian  Cuisine_Scottish  \
# 33004                  0                     0                 0
# 38713                  0                     0                 0
# 25929                  0                     0                 0
# 846                    0                     0                 0
# 14348                  0                     0                 0
#
#        Cuisine_Seafood  Cuisine_Shanghai  Cuisine_Sicilian  \
# 33004                0                 0                 0
# 38713                0                 0                 0
# 25929                0                 0                 0
# 846                  0                 0                 0
# 14348                0                 0                 0
#
#        Cuisine_Singaporean  Cuisine_Slovenian  Cuisine_Soups  \
# 33004                    0                  0              0
# 38713                    0                  0              0
# 25929                    0                  0              0
# 846                      0                  0              0
# 14348                    0                  0              0
#
#        Cuisine_South American  Cuisine_Southern-Italian  Cuisine_Southwestern  \
# 33004                       0                         0                     0
# 38713                       0                         0                     0
# 25929                       0                         0                     0
# 846                         0                         0                     0
# 14348                       0                         0                     0
#
#        Cuisine_Spanish  Cuisine_Specialty Food Market  Cuisine_Sri Lankan  \
# 33004                0                              0                   0
# 38713                0                              0                   0
# 25929                0                              0                   0
# 846                  0                              0                   0
# 14348                0                              0                   0
#
#        Cuisine_Steakhouse  Cuisine_Street Food  Cuisine_Sushi  \
# 33004                   0                    0              0
# 38713                   0                    0              0
# 25929                   0                    0              0
# 846                     0                    0              0
# 14348                   0                    0              0
#
#        Cuisine_Swedish  Cuisine_Swiss  Cuisine_Szechuan  Cuisine_Taiwanese  \
# 33004                0              0                 0                  0
# 38713                0              0                 0                  0
# 25929                0              0                 0                  0
# 846                  0              0                 0                  0
# 14348                0              0                 0                  0
#
#        Cuisine_Thai  Cuisine_Tibetan  Cuisine_Tunisian  Cuisine_Turkish  \
# 33004             0                0                 0                0
# 38713             0                0                 0                0
# 25929             0                0                 0                0
# 846               0                0                 0                0
# 14348             0                0                 0                0
#
#        Cuisine_Ukrainian  Cuisine_Uzbek  Cuisine_Vegan Options  \
# 33004                  0              0                      0
# 38713                  0              0                      0
# 25929                  0              0                      0
# 846                    0              0                      0
# 14348                  0              0                      0
#
#        Cuisine_Vegetarian Friendly  Cuisine_Venezuelan  Cuisine_Vietnamese  \
# 33004                            0                   0                   0
# 38713                            0                   0                   0
# 25929                            1                   0                   0
# 846                              1                   0                   0
# 14348                            0                   0                   0
#
#        Cuisine_Welsh  Cuisine_Wine Bar  Cuisine_Xinjiang  Cuisine_Yunnan  \
# 33004              0                 0                 0               0
# 38713              0                 1                 0               0
# 25929              0                 0                 0               0
# 846                0                 0                 0               0
# 14348              0                 0                 0               0
#
#        Cuisine_nan  City_Amsterdam  City_Athens  City_Barcelona  City_Berlin  \
# 33004            0               0            1               0            0
# 38713            0               0            1               0            0
# 25929            0               0            0               0            0
# 846              0               0            0               0            0
# 14348            0               0            0               0            0
#
#        City_Bratislava  City_Brussels  City_Budapest  City_Copenhagen  \
# 33004                0              0              0                0
# 38713                0              0              0                0
# 25929                0              0              0                0
# 846                  0              0              0                0
# 14348                0              0              0                0
#
#        City_Dublin  City_Edinburgh  City_Geneva  City_Hamburg  City_Helsinki  \
# 33004            0               0            0             0              0
# 38713            0               0            0             0              0
# 25929            0               0            0             0              0
# 846              0               0            0             0              0
# 14348            0               0            0             0              0
#
#        City_Krakow  City_Lisbon  City_Ljubljana  City_London  City_Luxembourg  \
# 33004            0            0               0            0                0
# 38713            0            0               0            0                0
# 25929            0            0               0            1                0
# 846              0            0               0            0                0
# 14348            0            0               0            1                0
#
#        City_Lyon  City_Madrid  City_Milan  City_Munich  City_Oporto  \
# 33004          0            0           0            0            0
# 38713          0            0           0            0            0
# 25929          0            0           0            0            0
# 846            0            0           1            0            0
# 14348          0            0           0            0            0
#
#        City_Oslo  City_Paris  City_Prague  City_Rome  City_Stockholm  \
# 33004          0           0            0          0               0
# 38713          0           0            0          0               0
# 25929          0           0            0          0               0
# 846            0           0            0          0               0
# 14348          0           0            0          0               0
#
#        City_Vienna  City_Warsaw  City_Zurich  City_nan
# 33004            0            0            0         0
# 38713            0            0            0         0
# 25929            0            0            0         0
# 846              0            0            0         0
# 14348            0            0            0         0

# %% [markdown]
# ### 3. Reviews

# %%
# ver 1.0
# df['Review'] = df['Reviews'].apply(parse_review, obj='Reviews')
# df = df.explode('Review')
# df.loc[:, ['Review', 'Review date']] = reviews_df.loc[:, ['Review', 'Review date']]

# # feature engineering
# df['Review year'] = df['Review date'].dt.year
# # df['Review month'] = df['Review date'].dt.month
# # df['Review day'] = df['Review date'].dt.day
# # df['Review day of week'] = df['Review date'].dt.dayofweek   # без них результат лучше
# df['Review day of year'] = df['Review date'].dt.dayofyear

# df.drop('Reviews', axis=1, inplace=True)
# df.reset_index(inplace=True, drop=True)
# df.sample(5)

# %%
# ver 2.0:
# найдем разницу во времени между отзывами:

def get_time_gap(row):
    return (row['Date 1'] - row['Date 2']).days if row['Date 1'] and row['Date 2'] else None


df['Time gap'] = df.apply(get_time_gap, axis=1)

# %%
# насколько стары отзывы:

def review_age(cell):
    return (now - cell).days if cell else None


now = datetime.now()
df['Review 1 age'] = df['Date 1'].apply(review_age)
df['Review 2 age'] = df['Date 2'].apply(review_age)

# %%
# какой день в году:
df['Review 1 day of year'] = df['Date 1'].dt.dayofyear
df['Review 2 day of year'] = df['Date 2'].dt.dayofyear

# %%
df.sample(3)

# %%
# длины отзывов (число слов):
df['Review 1 length'] = df['Review 1'].apply(lambda x: len(x.split()) if x else None)
df['Review 2 length'] = df['Review 2'].apply(lambda x: len(x.split()) if x else None)

# %%
# отзывы:
df[['Review 1', 'Review 2']].dropna().stack().value_counts()[47700:]

# каждое слово в отдельности:
# df[['Review 1', 'Review 2']].dropna().stack().apply(lambda x: x.split()).explode().apply(lambda x: x.lower() if len(x)>2 else None).value_counts()[30:60]

# %%
# оцифровываем отзывы: переведем оценочные суждения в отзывах в систему оценок. Т.к. нлп мы еще не владеем, проведем вручную:
impr_dict = {
    5: ['excellent', 'delicious', 'great', 'wonderful', 'very good', 'amazing', 'yummy', 'fantastic', 'lovely',
       'perfect', 'very nice', 'awesome', 'hidden gem', 'little gem', 'superb', 'brilliant', 'wow', 'loved', 'love', 
       'recommended', 'outstanding', 'fabulous', 'yum', 'delightful', 'surprise', 'surprised', 'best', 'enjoyable',
       'cool', 'really good', 'super', 'what a find', 'unique', 'charming', 'heaven'],
    4: ['good', 'not bad', 'nice', 'tasty', 'worth a visit', 'cheerful', 'pretty good', 'friendly', 'fine', 
        'better than expected', 'cozy', 'reasonable'],
    3: ['average', 'ok', 'nothing special', 'overpriced', 'not great', 'expensive', 'overrated', 'hit and miss',
       'not impressed', 'not too bad', 'mixed feelings', 'meh ', 'typical', 'standard'],
    2: ['disappointing', 'disappointed', 'bad', 'poor', 'below average', 'disappointment', 'rude', 'waste', 'wasting',
       'underwhelmed'],
    1: ['terrible', 'awful', 'avoid', 'horrible', 'very bad', 'stay away', 'rip off', 'disgusting', 'worst', 'closed']
}

impr_df = pd.DataFrame(dict([(k,pd.Series(v)) for k, v in impr_dict.items()]))

# def get_review_rate(cell):
#     for word in impr_df.values:
#         print(word, type(word))
# #         return ... if word in cell.lower() else None
#         if word in cell.lower():
#             print(impr_df[impr_df == word].columns)


def get_review_rate(cell):
    if cell:
        for mark in impr_dict:
            for word in impr_dict[mark]:
                if word in cell.lower():
                    return mark


df['Review 1 rate'] = df['Review 1'].apply(get_review_rate)
df['Review 2 rate'] = df['Review 2'].apply(get_review_rate)

# %%
df.sample(3)

# %%
df[['Review 1 length', 'Review 2 length', 'Review 1', 'Review 2']].info()

# %% [markdown]
# ## Ordinal parameters

# %%
price_ranges = {np.nan: 0, '$': 1, '$$ - $$$': 2, '$$$$': 3}
df['Price Range'] = df['Price Range'].apply(lambda x: price_ranges[x])

# %%
df.sample(3)
# Out:
#       Restaurant_id        City  \
# 18581        id_124  Copenhagen
# 15448      id_10050       Paris
# 12058        id_502      Geneva
#
#                                            Cuisine Style  Ranking  Rating  \
# 18581  ['Bar', 'Cafe', 'European', 'Scandinavian', 'D...    125.0     4.0
# 15448                 ['Chinese', 'Asian', 'Vietnamese']  10052.0     4.0
# 12058                             ['French', 'European']    505.0     4.5
#
#        Price Range  Number of Reviews  \
# 18581            2              244.0
# 15448            1               13.0
# 12058            2               58.0
#
#                                                  Reviews  \
# 18581  [['Worth of visiting', 'Nice place for good fo...
# 15448  [['Family atmosphere, great food.', 'very frie...
# 12058  [['Cool and cozy', 'Never a miss'], ['10/12/20...
#
#                                                   URL_TA     ID_TA  \
# 18581  /Restaurant_Review-g189541-d694941-Reviews-Caf...   d694941
# 15448  /Restaurant_Review-g187147-d7018592-Reviews-Ma...  d7018592
# 12058  /Restaurant_Review-g188057-d3749484-Reviews-Ch...  d3749484
#
#        Cuisine_Afghani  Cuisine_African  Cuisine_Albanian  Cuisine_Algerian  \
# 18581                0                0                 0                 0
# 15448                0                0                 0                 0
# 12058                0                0                 0                 0
#
#        Cuisine_American  Cuisine_Arabic  Cuisine_Argentinean  \
# 18581                 0               0                    0
# 15448                 0               0                    0
# 12058                 0               0                    0
#
#        Cuisine_Armenian  Cuisine_Asian  Cuisine_Australian  Cuisine_Austrian  \
# 18581                 0              0                   0                 0
# 15448                 0              1                   0                 0
# 12058                 0              0                   0                 0
#
#        Cuisine_Azerbaijani  Cuisine_Bakeries  Cuisine_Balti  \
# 18581                    0                 0              0
# 15448                    0                 0              0
# 12058                    0                 0              0
#
#        Cuisine_Bangladeshi  Cuisine_Bar  Cuisine_Barbecue  Cuisine_Basque  \
# 18581                    0            1                 0               0
# 15448                    0            0                 0               0
# 12058                    0            0                 0               0
#
#        Cuisine_Beer restaurants  Cuisine_Beijing Specialties  Cuisine_Belgian  \
# 18581                         0                            0                0
# 15448                         0                            0                0
# 12058                         0                            0                0
#
#        Cuisine_Brazilian  Cuisine_Brew Pub  Cuisine_British  Cuisine_Burmese  \
# 18581                  0                 0                0                0
# 15448                  0                 0                0                0
# 12058                  0                 0                0                0
#
#        Cuisine_Cafe  Cuisine_Cajun & Creole  Cuisine_Cambodian  \
# 18581             1                       0                  0
# 15448             0                       0                  0
# 12058             0                       0                  0
#
#        Cuisine_Campania  Cuisine_Canadian  Cuisine_Cantonese  \
# 18581                 0                 0                  0
# 15448                 0                 0                  0
# 12058                 0                 0                  0
#
#        Cuisine_Caribbean  Cuisine_Catalan  Cuisine_Caucasian  \
# 18581                  0                0                  0
# 15448                  0                0                  0
# 12058                  0                0                  0
#
#        Cuisine_Central American  Cuisine_Central Asian  \
# 18581                         0                      0
# 15448                         0                      0
# 12058                         0                      0
#
#        Cuisine_Central European  Cuisine_Central-Italian  Cuisine_Chilean  \
# 18581                         0                        0                0
# 15448                         0                        0                0
# 12058                         0                        0                0
#
#        Cuisine_Chinese  Cuisine_Colombian  Cuisine_Contemporary  \
# 18581                0                  0                     0
# 15448                1                  0                     0
# 12058                0                  0                     0
#
#        Cuisine_Croatian  Cuisine_Cuban  Cuisine_Czech  Cuisine_Danish  \
# 18581                 0              0              0               1
# 15448                 0              0              0               0
# 12058                 0              0              0               0
#
#        Cuisine_Deli  Cuisine_Delicatessen  Cuisine_Dessert  \
# 18581             0                     0                0
# 15448             0                     0                0
# 12058             0                     0                0
#
#        Cuisine_Dine With a Local Chef  Cuisine_Diner  Cuisine_Dining bars  \
# 18581                               0              0                    0
# 15448                               0              0                    0
# 12058                               0              0                    0
#
#        Cuisine_Dutch  Cuisine_Eastern European  Cuisine_Ecuadorean  \
# 18581              0                         0                   0
# 15448              0                         0                   0
# 12058              0                         0                   0
#
#        Cuisine_Egyptian  Cuisine_Ethiopian  Cuisine_European  \
# 18581                 0                  0                 1
# 15448                 0                  0                 0
# 12058                 0                  0                 1
#
#        Cuisine_Fast Food  Cuisine_Filipino  Cuisine_French  Cuisine_Fujian  \
# 18581                  0                 0               0               0
# 15448                  0                 0               0               0
# 12058                  0                 0               1               0
#
#        Cuisine_Fusion  Cuisine_Gastropub  Cuisine_Georgian  Cuisine_German  \
# 18581               0                  0                 0               0
# 15448               0                  0                 0               0
# 12058               0                  0                 0               0
#
#        Cuisine_Gluten Free Options  Cuisine_Greek  Cuisine_Grill  \
# 18581                            1              0              0
# 15448                            0              0              0
# 12058                            0              0              0
#
#        Cuisine_Halal  Cuisine_Hawaiian  Cuisine_Healthy  Cuisine_Hong Kong  \
# 18581              0                 0                0                  0
# 15448              0                 0                0                  0
# 12058              0                 0                0                  0
#
#        Cuisine_Hungarian  Cuisine_Imperial Chinese  Cuisine_Indian  \
# 18581                  0                         0               0
# 15448                  0                         0               0
# 12058                  0                         0               0
#
#        Cuisine_Indonesian  Cuisine_International  Cuisine_Irish  \
# 18581                   0                      0              0
# 15448                   0                      0              0
# 12058                   0                      0              0
#
#        Cuisine_Israeli  Cuisine_Italian  Cuisine_Jamaican  Cuisine_Japanese  \
# 18581                0                0                 0                 0
# 15448                0                0                 0                 0
# 12058                0                0                 0                 0
#
#        Cuisine_Japanese Fusion  Cuisine_Korean  Cuisine_Kosher  Cuisine_Latin  \
# 18581                        0               0               0              0
# 15448                        0               0               0              0
# 12058                        0               0               0              0
#
#        Cuisine_Latvian  Cuisine_Lazio  Cuisine_Lebanese  Cuisine_Lombard  \
# 18581                0              0                 0                0
# 15448                0              0                 0                0
# 12058                0              0                 0                0
#
#        Cuisine_Malaysian  Cuisine_Mediterranean  Cuisine_Mexican  \
# 18581                  0                      0                0
# 15448                  0                      0                0
# 12058                  0                      0                0
#
#        Cuisine_Middle Eastern  Cuisine_Minority Chinese  Cuisine_Mongolian  \
# 18581                       0                         0                  0
# 15448                       0                         0                  0
# 12058                       0                         0                  0
#
#        Cuisine_Moroccan  Cuisine_Native American  Cuisine_Neapolitan  \
# 18581                 0                        0                   0
# 15448                 0                        0                   0
# 12058                 0                        0                   0
#
#        Cuisine_Nepali  Cuisine_New Zealand  Cuisine_NorthEastern Chinese  \
# 18581               0                    0                             0
# 15448               0                    0                             0
# 12058               0                    0                             0
#
#        Cuisine_NorthWestern Chinese  Cuisine_Northern-Italian  \
# 18581                             0                         0
# 15448                             0                         0
# 12058                             0                         0
#
#        Cuisine_Norwegian  Cuisine_Pakistani  Cuisine_Persian  \
# 18581                  0                  0                0
# 15448                  0                  0                0
# 12058                  0                  0                0
#
#        Cuisine_Peruvian  Cuisine_Pizza  Cuisine_Polish  Cuisine_Polynesian  \
# 18581                 0              0               0                   0
# 15448                 0              0               0                   0
# 12058                 0              0               0                   0
#
#        Cuisine_Portuguese  Cuisine_Pub  Cuisine_Quick Bites  Cuisine_Romana  \
# 18581                   0            0                    0               0
# 15448                   0            0                    0               0
# 12058                   0            0                    0               0
#
#        Cuisine_Romanian  Cuisine_Russian  Cuisine_Salvadoran  \
# 18581                 0                0                   0
# 15448                 0                0                   0
# 12058                 0                0                   0
#
#        Cuisine_Sardinian  Cuisine_Scandinavian  Cuisine_Scottish  \
# 18581                  0                     1                 0
# 15448                  0                     0                 0
# 12058                  0                     0                 0
#
#        Cuisine_Seafood  Cuisine_Shanghai  Cuisine_Sicilian  \
# 18581                0                 0                 0
# 15448                0                 0                 0
# 12058                0                 0                 0
#
#        Cuisine_Singaporean  Cuisine_Slovenian  Cuisine_Soups  \
# 18581                    0                  0              0
# 15448                    0                  0              0
# 12058                    0                  0              0
#
#        Cuisine_South American  Cuisine_Southern-Italian  Cuisine_Southwestern  \
# 18581                       0                         0                     0
# 15448                       0                         0                     0
# 12058                       0                         0                     0
#
#        Cuisine_Spanish  Cuisine_Specialty Food Market  Cuisine_Sri Lankan  \
# 18581                0                              0                   0
# 15448                0                              0                   0
# 12058                0                              0                   0
#
#        Cuisine_Steakhouse  Cuisine_Street Food  Cuisine_Sushi  \
# 18581                   0                    0              0
# 15448                   0                    0              0
# 12058                   0                    0              0
#
#        Cuisine_Swedish  Cuisine_Swiss  Cuisine_Szechuan  Cuisine_Taiwanese  \
# 18581                0              0                 0                  0
# 15448                0              0                 0                  0
# 12058                0              0                 0                  0
#
#        Cuisine_Thai  Cuisine_Tibetan  Cuisine_Tunisian  Cuisine_Turkish  \
# 18581             0                0                 0                0
# 15448             0                0                 0                0
# 12058             0                0                 0                0
#
#        Cuisine_Ukrainian  Cuisine_Uzbek  Cuisine_Vegan Options  \
# 18581                  0              0                      0
# 15448                  0              0                      0
# 12058                  0              0                      0
#
#        Cuisine_Vegetarian Friendly  Cuisine_Venezuelan  Cuisine_Vietnamese  \
# 18581                            1                   0                   0
# 15448                            0                   0                   1
# 12058                            0                   0                   0
#
#        Cuisine_Welsh  Cuisine_Wine Bar  Cuisine_Xinjiang  Cuisine_Yunnan  \
# 18581              0                 0                 0               0
# 15448              0                 0                 0               0
# 12058              0                 0                 0               0
#
#        Cuisine_nan  City_Amsterdam  City_Athens  City_Barcelona  City_Berlin  \
# 18581            0               0            0               0            0
# 15448            0               0            0               0            0
# 12058            0               0            0               0            0
#
#        City_Bratislava  City_Brussels  City_Budapest  City_Copenhagen  \
# 18581                0              0              0                1
# 15448                0              0              0                0
# 12058                0              0              0                0
#
#        City_Dublin  City_Edinburgh  City_Geneva  City_Hamburg  City_Helsinki  \
# 18581            0               0            0             0              0
# 15448            0               0            0             0              0
# 12058            0               0            1             0              0
#
#        City_Krakow  City_Lisbon  City_Ljubljana  City_London  City_Luxembourg  \
# 18581            0            0               0            0                0
# 15448            0            0               0            0                0
# 12058            0            0               0            0                0
#
#        City_Lyon  City_Madrid  City_Milan  City_Munich  City_Oporto  \
# 18581          0            0           0            0            0
# 15448          0            0           0            0            0
# 12058          0            0           0            0            0
#
#        City_Oslo  City_Paris  City_Prague  City_Rome  City_Stockholm  \
# 18581          0           0            0          0               0
# 15448          0           1            0          0               0
# 12058          0           0            0          0               0
#
#        City_Vienna  City_Warsaw  City_Zurich  City_nan
# 18581            0            0            0         0
# 15448            0            0            0         0
# 12058            0            0            0         0

# %% [markdown]
# ### Заполнение пропусков в Price Range

# %%
df[df['Restaurant_geo'] == 'Barcelona_Catalonia']['Price Range'].hist()

# %%
df[(df['Restaurant_geo'] == 'Barcelona_Catalonia') & (df['Cuisine Style'] == "['Mediterranean']")]['Price Range'].hist()

# %%
df['Restaurant_geo'].value_counts()

# %%
df[df['Restaurant_geo'] == 'Barcelona_Catalonia']['Cuisine Style'].value_counts()

# %% [markdown]
# Заполнять пропуски в этой колонке нужно осмысленно, значения зависят от разных факторов, например одновременно от города и стиля кухни - видно по разному характеру графиков, когда во внимание берется один или два параметра.
#
# Доделаю эту работу похже.

# %% [markdown]
# ## Удаляем текстовые признаки

# %%
df.sample()
# Out:
#       Restaurant_id    City   Cuisine Style  Ranking  Rating  Price Range  \
# 30842      id_10874  London  ['Vietnamese']  10884.0     4.5            0
#
#        Number of Reviews                                            Reviews  \
# 30842                4.0  [['Pho king Amazing!', 'Simplebut nice vietnam...
#
#                                                   URL_TA     ID_TA  \
# 30842  /Restaurant_Review-g186338-d5508996-Reviews-Ne...  d5508996
#
#        Cuisine_Afghani  Cuisine_African  Cuisine_Albanian  Cuisine_Algerian  \
# 30842                0                0                 0                 0
#
#        Cuisine_American  Cuisine_Arabic  Cuisine_Argentinean  \
# 30842                 0               0                    0
#
#        Cuisine_Armenian  Cuisine_Asian  Cuisine_Australian  Cuisine_Austrian  \
# 30842                 0              0                   0                 0
#
#        Cuisine_Azerbaijani  Cuisine_Bakeries  Cuisine_Balti  \
# 30842                    0                 0              0
#
#        Cuisine_Bangladeshi  Cuisine_Bar  Cuisine_Barbecue  Cuisine_Basque  \
# 30842                    0            0                 0               0
#
#        Cuisine_Beer restaurants  Cuisine_Beijing Specialties  Cuisine_Belgian  \
# 30842                         0                            0                0
#
#        Cuisine_Brazilian  Cuisine_Brew Pub  Cuisine_British  Cuisine_Burmese  \
# 30842                  0                 0                0                0
#
#        Cuisine_Cafe  Cuisine_Cajun & Creole  Cuisine_Cambodian  \
# 30842             0                       0                  0
#
#        Cuisine_Campania  Cuisine_Canadian  Cuisine_Cantonese  \
# 30842                 0                 0                  0
#
#        Cuisine_Caribbean  Cuisine_Catalan  Cuisine_Caucasian  \
# 30842                  0                0                  0
#
#        Cuisine_Central American  Cuisine_Central Asian  \
# 30842                         0                      0
#
#        Cuisine_Central European  Cuisine_Central-Italian  Cuisine_Chilean  \
# 30842                         0                        0                0
#
#        Cuisine_Chinese  Cuisine_Colombian  Cuisine_Contemporary  \
# 30842                0                  0                     0
#
#        Cuisine_Croatian  Cuisine_Cuban  Cuisine_Czech  Cuisine_Danish  \
# 30842                 0              0              0               0
#
#        Cuisine_Deli  Cuisine_Delicatessen  Cuisine_Dessert  \
# 30842             0                     0                0
#
#        Cuisine_Dine With a Local Chef  Cuisine_Diner  Cuisine_Dining bars  \
# 30842                               0              0                    0
#
#        Cuisine_Dutch  Cuisine_Eastern European  Cuisine_Ecuadorean  \
# 30842              0                         0                   0
#
#        Cuisine_Egyptian  Cuisine_Ethiopian  Cuisine_European  \
# 30842                 0                  0                 0
#
#        Cuisine_Fast Food  Cuisine_Filipino  Cuisine_French  Cuisine_Fujian  \
# 30842                  0                 0               0               0
#
#        Cuisine_Fusion  Cuisine_Gastropub  Cuisine_Georgian  Cuisine_German  \
# 30842               0                  0                 0               0
#
#        Cuisine_Gluten Free Options  Cuisine_Greek  Cuisine_Grill  \
# 30842                            0              0              0
#
#        Cuisine_Halal  Cuisine_Hawaiian  Cuisine_Healthy  Cuisine_Hong Kong  \
# 30842              0                 0                0                  0
#
#        Cuisine_Hungarian  Cuisine_Imperial Chinese  Cuisine_Indian  \
# 30842                  0                         0               0
#
#        Cuisine_Indonesian  Cuisine_International  Cuisine_Irish  \
# 30842                   0                      0              0
#
#        Cuisine_Israeli  Cuisine_Italian  Cuisine_Jamaican  Cuisine_Japanese  \
# 30842                0                0                 0                 0
#
#        Cuisine_Japanese Fusion  Cuisine_Korean  Cuisine_Kosher  Cuisine_Latin  \
# 30842                        0               0               0              0
#
#        Cuisine_Latvian  Cuisine_Lazio  Cuisine_Lebanese  Cuisine_Lombard  \
# 30842                0              0                 0                0
#
#        Cuisine_Malaysian  Cuisine_Mediterranean  Cuisine_Mexican  \
# 30842                  0                      0                0
#
#        Cuisine_Middle Eastern  Cuisine_Minority Chinese  Cuisine_Mongolian  \
# 30842                       0                         0                  0
#
#        Cuisine_Moroccan  Cuisine_Native American  Cuisine_Neapolitan  \
# 30842                 0                        0                   0
#
#        Cuisine_Nepali  Cuisine_New Zealand  Cuisine_NorthEastern Chinese  \
# 30842               0                    0                             0
#
#        Cuisine_NorthWestern Chinese  Cuisine_Northern-Italian  \
# 30842                             0                         0
#
#        Cuisine_Norwegian  Cuisine_Pakistani  Cuisine_Persian  \
# 30842                  0                  0                0
#
#        Cuisine_Peruvian  Cuisine_Pizza  Cuisine_Polish  Cuisine_Polynesian  \
# 30842                 0              0               0                   0
#
#        Cuisine_Portuguese  Cuisine_Pub  Cuisine_Quick Bites  Cuisine_Romana  \
# 30842                   0            0                    0               0
#
#        Cuisine_Romanian  Cuisine_Russian  Cuisine_Salvadoran  \
# 30842                 0                0                   0
#
#        Cuisine_Sardinian  Cuisine_Scandinavian  Cuisine_Scottish  \
# 30842                  0                     0                 0
#
#        Cuisine_Seafood  Cuisine_Shanghai  Cuisine_Sicilian  \
# 30842                0                 0                 0
#
#        Cuisine_Singaporean  Cuisine_Slovenian  Cuisine_Soups  \
# 30842                    0                  0              0
#
#        Cuisine_South American  Cuisine_Southern-Italian  Cuisine_Southwestern  \
# 30842                       0                         0                     0
#
#        Cuisine_Spanish  Cuisine_Specialty Food Market  Cuisine_Sri Lankan  \
# 30842                0                              0                   0
#
#        Cuisine_Steakhouse  Cuisine_Street Food  Cuisine_Sushi  \
# 30842                   0                    0              0
#
#        Cuisine_Swedish  Cuisine_Swiss  Cuisine_Szechuan  Cuisine_Taiwanese  \
# 30842                0              0                 0                  0
#
#        Cuisine_Thai  Cuisine_Tibetan  Cuisine_Tunisian  Cuisine_Turkish  \
# 30842             0                0                 0                0
#
#        Cuisine_Ukrainian  Cuisine_Uzbek  Cuisine_Vegan Options  \
# 30842                  0              0                      0
#
#        Cuisine_Vegetarian Friendly  Cuisine_Venezuelan  Cuisine_Vietnamese  \
# 30842                            0                   0                   1
#
#        Cuisine_Welsh  Cuisine_Wine Bar  Cuisine_Xinjiang  Cuisine_Yunnan  \
# 30842              0                 0                 0               0
#
#        Cuisine_nan  City_Amsterdam  City_Athens  City_Barcelona  City_Berlin  \
# 30842            0               0            0               0            0
#
#        City_Bratislava  City_Brussels  City_Budapest  City_Copenhagen  \
# 30842                0              0              0                0
#
#        City_Dublin  City_Edinburgh  City_Geneva  City_Hamburg  City_Helsinki  \
# 30842            0               0            0             0              0
#
#        City_Krakow  City_Lisbon  City_Ljubljana  City_London  City_Luxembourg  \
# 30842            0            0               0            1                0
#
#        City_Lyon  City_Madrid  City_Milan  City_Munich  City_Oporto  \
# 30842          0            0           0            0            0
#
#        City_Oslo  City_Paris  City_Prague  City_Rome  City_Stockholm  \
# 30842          0           0            0          0               0
#
#        City_Vienna  City_Warsaw  City_Zurich  City_nan
# 30842            0            0            0         0

# %%
obj_cols2 = ['City', 'Cuisine Style', 'ID_TA', 'Reviews', 'URL_TA']
df = df.drop(obj_cols2, axis=1)
df.fillna(df.median(), inplace=True)   # filling in with means

df.sample(5)
# Out:
#       Restaurant_id  Ranking  Rating  Price Range  Number of Reviews  \
# 31881        id_726    727.0     4.0            2               30.0
# 32786        id_240    241.0     4.5            2              171.0
# 4702        id_8493   8495.0     4.0            3               38.0
# 8438        id_5127   5130.0     4.0            2                8.0
# 16554        id_574    575.0     4.0            2               29.0
#
#        Cuisine_Afghani  Cuisine_African  Cuisine_Albanian  Cuisine_Algerian  \
# 31881                0                0                 0                 0
# 32786                0                0                 0                 0
# 4702                 0                0                 0                 0
# 8438                 0                0                 0                 0
# 16554                0                0                 0                 0
#
#        Cuisine_American  Cuisine_Arabic  Cuisine_Argentinean  \
# 31881                 0               0                    0
# 32786                 0               0                    0
# 4702                  0               0                    0
# 8438                  0               0                    0
# 16554                 0               0                    0
#
#        Cuisine_Armenian  Cuisine_Asian  Cuisine_Australian  Cuisine_Austrian  \
# 31881                 0              0                   0                 0
# 32786                 0              0                   0                 0
# 4702                  0              0                   0                 0
# 8438                  0              0                   0                 0
# 16554                 0              0                   0                 0
#
#        Cuisine_Azerbaijani  Cuisine_Bakeries  Cuisine_Balti  \
# 31881                    0                 0              0
# 32786                    0                 0              0
# 4702                     0                 0              0
# 8438                     0                 0              0
# 16554                    0                 0              0
#
#        Cuisine_Bangladeshi  Cuisine_Bar  Cuisine_Barbecue  Cuisine_Basque  \
# 31881                    0            0                 0               0
# 32786                    0            0                 0               0
# 4702                     0            0                 0               0
# 8438                     0            0                 0               0
# 16554                    0            0                 0               0
#
#        Cuisine_Beer restaurants  Cuisine_Beijing Specialties  Cuisine_Belgian  \
# 31881                         0                            0                0
# 32786                         0                            0                0
# 4702                          0                            0                0
# 8438                          0                            0                0
# 16554                         0                            0                0
#
#        Cuisine_Brazilian  Cuisine_Brew Pub  Cuisine_British  Cuisine_Burmese  \
# 31881                  0                 0                0                0
# 32786                  0                 0                1                0
# 4702                   0                 0                0                0
# 8438                   0                 0                0                0
# 16554                  0                 0                0                0
#
#        Cuisine_Cafe  Cuisine_Cajun & Creole  Cuisine_Cambodian  \
# 31881             0                       0                  0
# 32786             0                       0                  0
# 4702              0                       0                  0
# 8438              1                       0                  0
# 16554             0                       0                  0
#
#        Cuisine_Campania  Cuisine_Canadian  Cuisine_Cantonese  \
# 31881                 0                 0                  0
# 32786                 0                 0                  0
# 4702                  0                 0                  0
# 8438                  0                 0                  0
# 16554                 0                 0                  0
#
#        Cuisine_Caribbean  Cuisine_Catalan  Cuisine_Caucasian  \
# 31881                  0                0                  0
# 32786                  0                0                  0
# 4702                   0                0                  0
# 8438                   0                0                  0
# 16554                  0                0                  0
#
#        Cuisine_Central American  Cuisine_Central Asian  \
# 31881                         0                      0
# 32786                         0                      0
# 4702                          0                      0
# 8438                          0                      0
# 16554                         0                      0
#
#        Cuisine_Central European  Cuisine_Central-Italian  Cuisine_Chilean  \
# 31881                         0                        0                0
# 32786                         0                        0                0
# 4702                          0                        0                0
# 8438                          0                        0                0
# 16554                         0                        0                0
#
#        Cuisine_Chinese  Cuisine_Colombian  Cuisine_Contemporary  \
# 31881                0                  0                     0
# 32786                0                  0                     0
# 4702                 0                  0                     0
# 8438                 0                  0                     0
# 16554                0                  0                     0
#
#        Cuisine_Croatian  Cuisine_Cuban  Cuisine_Czech  Cuisine_Danish  \
# 31881                 0              0              0               0
# 32786                 0              0              0               0
# 4702                  0              0              0               0
# 8438                  0              0              0               0
# 16554                 0              0              0               0
#
#        Cuisine_Deli  Cuisine_Delicatessen  Cuisine_Dessert  \
# 31881             0                     0                0
# 32786             0                     0                0
# 4702              0                     0                0
# 8438              0                     0                0
# 16554             0                     0                0
#
#        Cuisine_Dine With a Local Chef  Cuisine_Diner  Cuisine_Dining bars  \
# 31881                               0              0                    0
# 32786                               0              0                    0
# 4702                                0              0                    0
# 8438                                0              0                    0
# 16554                               0              0                    0
#
#        Cuisine_Dutch  Cuisine_Eastern European  Cuisine_Ecuadorean  \
# 31881              0                         0                   0
# 32786              0                         0                   0
# 4702               0                         0                   0
# 8438               0                         0                   0
# 16554              0                         0                   0
#
#        Cuisine_Egyptian  Cuisine_Ethiopian  Cuisine_European  \
# 31881                 0                  0                 0
# 32786                 0                  0                 1
# 4702                  0                  0                 0
# 8438                  0                  0                 1
# 16554                 0                  0                 0
#
#        Cuisine_Fast Food  Cuisine_Filipino  Cuisine_French  Cuisine_Fujian  \
# 31881                  0                 0               0               0
# 32786                  0                 0               0               0
# 4702                   0                 0               1               0
# 8438                   0                 0               1               0
# 16554                  0                 0               0               0
#
#        Cuisine_Fusion  Cuisine_Gastropub  Cuisine_Georgian  Cuisine_German  \
# 31881               0                  0                 0               0
# 32786               0                  0                 0               0
# 4702                0                  0                 0               0
# 8438                0                  0                 0               0
# 16554               0                  0                 0               0
#
#        Cuisine_Gluten Free Options  Cuisine_Greek  Cuisine_Grill  \
# 31881                            0              0              0
# 32786                            1              0              0
# 4702                             0              0              0
# 8438                             0              0              0
# 16554                            0              0              0
#
#        Cuisine_Halal  Cuisine_Hawaiian  Cuisine_Healthy  Cuisine_Hong Kong  \
# 31881              0                 0                0                  0
# 32786              0                 0                0                  0
# 4702               0                 0                0                  0
# 8438               0                 0                0                  0
# 16554              0                 0                0                  0
#
#        Cuisine_Hungarian  Cuisine_Imperial Chinese  Cuisine_Indian  \
# 31881                  0                         0               0
# 32786                  0                         0               0
# 4702                   0                         0               0
# 8438                   0                         0               0
# 16554                  0                         0               0
#
#        Cuisine_Indonesian  Cuisine_International  Cuisine_Irish  \
# 31881                   0                      0              0
# 32786                   0                      0              0
# 4702                    0                      0              0
# 8438                    0                      0              0
# 16554                   0                      0              0
#
#        Cuisine_Israeli  Cuisine_Italian  Cuisine_Jamaican  Cuisine_Japanese  \
# 31881                0                0                 0                 0
# 32786                0                0                 0                 0
# 4702                 0                0                 0                 0
# 8438                 0                0                 0                 0
# 16554                0                0                 0                 0
#
#        Cuisine_Japanese Fusion  Cuisine_Korean  Cuisine_Kosher  Cuisine_Latin  \
# 31881                        0               0               0              0
# 32786                        0               0               0              0
# 4702                         0               0               0              0
# 8438                         0               0               0              0
# 16554                        0               0               0              0
#
#        Cuisine_Latvian  Cuisine_Lazio  Cuisine_Lebanese  Cuisine_Lombard  \
# 31881                0              0                 0                0
# 32786                0              0                 0                0
# 4702                 0              0                 0                0
# 8438                 0              0                 0                0
# 16554                0              0                 0                0
#
#        Cuisine_Malaysian  Cuisine_Mediterranean  Cuisine_Mexican  \
# 31881                  0                      0                0
# 32786                  0                      0                0
# 4702                   0                      0                0
# 8438                   0                      0                0
# 16554                  0                      0                0
#
#        Cuisine_Middle Eastern  Cuisine_Minority Chinese  Cuisine_Mongolian  \
# 31881                       0                         0                  0
# 32786                       0                         0                  0
# 4702                        0                         0                  0
# 8438                        0                         0                  0
# 16554                       0                         0                  0
#
#        Cuisine_Moroccan  Cuisine_Native American  Cuisine_Neapolitan  \
# 31881                 0                        0                   0
# 32786                 0                        0                   0
# 4702                  0                        0                   0
# 8438                  0                        0                   0
# 16554                 0                        0                   0
#
#        Cuisine_Nepali  Cuisine_New Zealand  Cuisine_NorthEastern Chinese  \
# 31881               0                    0                             0
# 32786               0                    0                             0
# 4702                0                    0                             0
# 8438                0                    0                             0
# 16554               0                    0                             0
#
#        Cuisine_NorthWestern Chinese  Cuisine_Northern-Italian  \
# 31881                             0                         0
# 32786                             0                         0
# 4702                              0                         0
# 8438                              0                         0
# 16554                             0                         0
#
#        Cuisine_Norwegian  Cuisine_Pakistani  Cuisine_Persian  \
# 31881                  0                  0                0
# 32786                  0                  0                0
# 4702                   0                  0                0
# 8438                   0                  0                0
# 16554                  0                  0                0
#
#        Cuisine_Peruvian  Cuisine_Pizza  Cuisine_Polish  Cuisine_Polynesian  \
# 31881                 0              0               0                   0
# 32786                 0              0               0                   0
# 4702                  0              0               0                   0
# 8438                  0              0               0                   0
# 16554                 0              0               0                   0
#
#        Cuisine_Portuguese  Cuisine_Pub  Cuisine_Quick Bites  Cuisine_Romana  \
# 31881                   0            0                    0               0
# 32786                   0            0                    0               0
# 4702                    0            0                    0               0
# 8438                    0            0                    0               0
# 16554                   0            0                    0               0
#
#        Cuisine_Romanian  Cuisine_Russian  Cuisine_Salvadoran  \
# 31881                 0                0                   0
# 32786                 0                0                   0
# 4702                  0                0                   0
# 8438                  0                0                   0
# 16554                 0                0                   0
#
#        Cuisine_Sardinian  Cuisine_Scandinavian  Cuisine_Scottish  \
# 31881                  0                     0                 0
# 32786                  0                     1                 1
# 4702                   0                     0                 0
# 8438                   0                     0                 0
# 16554                  0                     0                 0
#
#        Cuisine_Seafood  Cuisine_Shanghai  Cuisine_Sicilian  \
# 31881                0                 0                 0
# 32786                0                 0                 0
# 4702                 0                 0                 0
# 8438                 0                 0                 0
# 16554                0                 0                 0
#
#        Cuisine_Singaporean  Cuisine_Slovenian  Cuisine_Soups  \
# 31881                    0                  0              0
# 32786                    0                  0              0
# 4702                     0                  0              0
# 8438                     0                  0              0
# 16554                    0                  0              0
#
#        Cuisine_South American  Cuisine_Southern-Italian  Cuisine_Southwestern  \
# 31881                       0                         0                     0
# 32786                       0                         0                     0
# 4702                        0                         0                     0
# 8438                        0                         0                     0
# 16554                       0                         0                     0
#
#        Cuisine_Spanish  Cuisine_Specialty Food Market  Cuisine_Sri Lankan  \
# 31881                0                              0                   0
# 32786                0                              0                   0
# 4702                 0                              0                   0
# 8438                 0                              0                   0
# 16554                0                              0                   0
#
#        Cuisine_Steakhouse  Cuisine_Street Food  Cuisine_Sushi  \
# 31881                   0                    0              0
# 32786                   0                    0              0
# 4702                    0                    0              0
# 8438                    0                    0              0
# 16554                   0                    0              1
#
#        Cuisine_Swedish  Cuisine_Swiss  Cuisine_Szechuan  Cuisine_Taiwanese  \
# 31881                0              0                 0                  0
# 32786                0              0                 0                  0
# 4702                 0              0                 0                  0
# 8438                 0              0                 0                  0
# 16554                0              0                 0                  0
#
#        Cuisine_Thai  Cuisine_Tibetan  Cuisine_Tunisian  Cuisine_Turkish  \
# 31881             1                0                 0                0
# 32786             0                0                 0                0
# 4702              0                0                 0                0
# 8438              0                0                 0                0
# 16554             1                0                 0                0
#
#        Cuisine_Ukrainian  Cuisine_Uzbek  Cuisine_Vegan Options  \
# 31881                  0              0                      0
# 32786                  0              0                      1
# 4702                   0              0                      0
# 8438                   0              0                      0
# 16554                  0              0                      0
#
#        Cuisine_Vegetarian Friendly  Cuisine_Venezuelan  Cuisine_Vietnamese  \
# 31881                            0                   0                   0
# 32786                            1                   0                   0
# 4702                             0                   0                   0
# 8438                             0                   0                   0
# 16554                            1                   0                   0
#
#        Cuisine_Welsh  Cuisine_Wine Bar  Cuisine_Xinjiang  Cuisine_Yunnan  \
# 31881              0                 0                 0               0
# 32786              0                 0                 0               0
# 4702               0                 0                 0               0
# 8438               0                 0                 0               0
# 16554              0                 0                 0               0
#
#        Cuisine_nan  City_Amsterdam  City_Athens  City_Barcelona  City_Berlin  \
# 31881            0               0            0               0            0
# 32786            0               0            0               0            0
# 4702             0               0            0               0            0
# 8438             0               0            0               0            0
# 16554            0               0            0               0            0
#
#        City_Bratislava  City_Brussels  City_Budapest  City_Copenhagen  \
# 31881                0              0              0                1
# 32786                0              0              0                0
# 4702                 0              0              0                0
# 8438                 0              0              0                0
# 16554                0              0              0                0
#
#        City_Dublin  City_Edinburgh  City_Geneva  City_Hamburg  City_Helsinki  \
# 31881            0               0            0             0              0
# 32786            0               1            0             0              0
# 4702             0               0            0             0              0
# 8438             0               0            0             0              0
# 16554            0               0            0             0              0
#
#        City_Krakow  City_Lisbon  City_Ljubljana  City_London  City_Luxembourg  \
# 31881            0            0               0            0                0
# 32786            0            0               0            0                0
# 4702             0            0               0            0                0
# 8438             0            0               0            0                0
# 16554            0            0               0            0                0
#
#        City_Lyon  City_Madrid  City_Milan  City_Munich  City_Oporto  \
# 31881          0            0           0            0            0
# 32786          0            0           0            0            0
# 4702           0            0           0            0            0
# 8438           0            1           0            0            0
# 16554          0            0           0            0            0
#
#        City_Oslo  City_Paris  City_Prague  City_Rome  City_Stockholm  \
# 31881          0           0            0          0               0
# 32786          0           0            0          0               0
# 4702           0           1            0          0               0
# 8438           0           0            0          0               0
# 16554          0           0            0          0               0
#
#        City_Vienna  City_Warsaw  City_Zurich  City_nan
# 31881            0            0            0         0
# 32786            0            0            0         0
# 4702             0            0            0         0
# 8438             0            0            0         0
# 16554            0            1            0         0

# %%
# v 2.0 for ML
# obj_cols = ['Restaurant_id', 'City', 'Cuisine Style', 'Price Range', 'URL_TA', 'ID_TA', 'Review', 'Review date']
# obj_cols1 = ['City', 'Cuisine Style', 'Price Range', 'URL_TA', 'ID_TA', 'Review', 'Review date']
obj_cols2 = ['City', 'Cuisine Style', 'ID_TA', 'Review 1', 'Review 2', 'Date 1', 'Date 2', 'URL_TA', 'URL_g', 'URL_d', 'Restaurant_title', 'Restaurant_geo']
df = df.drop(obj_cols2, axis=1)

# values = {col: df[col].mean() for col in 
#           ['Ranking', 'Rating', 'Number of Reviews', 'Review year', 'Review month', 'Review day']}
# values = {col: df[col].mean() for col in 
#           ['Ranking', 'Rating', 'Number of Reviews', 'Review year', 'Review day of year']}
# print(values)
df.fillna(df.median(), inplace=True)   # filling in with means

df.sample(5)

# %%
# df.drop_duplicates(ignore_index=True, inplace=True)

# %%
# v 1.0 for ML
# df = pd.read_csv('main_task.csv')

# # obj_cols = ['Restaurant_id', 'City', 'Cuisine Style', 'Price Range', 'Reviews', 'URL_TA', 'ID_TA']
# obj_cols = ['City', 'Cuisine Style', 'Price Range', 'Reviews', 'URL_TA', 'ID_TA']

# df = df.drop(col_drop, axis=1)
# # df.fillna(0, inplace=True)

# values = {col: df[col].mean() for col in df.columns}
# df.fillna(values, inplace=True)

# df.sample(5)

# %% [markdown]
# # Разбиваем датафрейм на части, необходимые для обучения и тестирования модели

# %%
# Х - данные с информацией о ресторанах, у - целевая переменная (рейтинги ресторанов)
# X = df.drop(['Restaurant_id', 'Rating'], axis = 1)
# X = df.drop(['Rating'], axis = 1)
# y = df['Rating']
X = df.drop(['Restaurant_id', 'Rating'], axis = 1)
y = df['Rating']

# %%
# Загружаем специальный инструмент для разбивки:
from sklearn.model_selection import train_test_split

# %%
# Наборы данных с меткой "train" будут использоваться для обучения модели, "test" - для тестирования.
# Для тестирования мы будем использовать 25% от исходного датасета.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (30000, 191) (10000, 191) (30000,) (10000,)

# %% [markdown]
# # Создаём, обучаем и тестируем модель

# %%
# Импортируем необходимые библиотеки:
from sklearn.ensemble import RandomForestRegressor # инструмент для создания и обучения модели
from sklearn import metrics # инструменты для оценки точности модели

# %%
# Создаём модель
regr = RandomForestRegressor(n_estimators=100)

# Обучаем модель на тестовом наборе данных
regr.fit(X_train, y_train)

# Используем обученную модель для предсказания рейтинга ресторанов в тестовой выборке.
# Предсказанные значения записываем в переменную y_pred
y_pred = regr.predict(X_test)

# %%
# Сравниваем предсказанные значения (y_pred) с реальными (y_test), и смотрим насколько они в среднем отличаются
# Метрика называется Mean Absolute Error (MAE) и показывает среднее отклонение предсказанных значений от фактических.
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MAE: 0.22482399999999997

# %% [markdown]
# # Записываем результат для сабмита

# %%
result = pd.DataFrame(df.iloc[X_test.index]['Restaurant_id'])
result['Rating'] = y_pred
result['Rest_id'] = result['Restaurant_id'].apply(lambda x: int(x[3:]))
result = result.sort_values('Rest_id')#.drop_duplicates(subset=['Restaurant_id'])
result = result.drop('Rest_id', axis=1)
result.head(20)

# %%
result.info()

# %%
submit_time = datetime.now().strftime('%Y.%m.%d %H-%M')
filename = submit_time + ' rds3_Walrave.csv'
result.to_csv(path_or_buf=filename, index=False)

# %%
pd.read_csv(filename)
