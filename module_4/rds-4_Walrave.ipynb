# %% [markdown]
# # Проект 4. Авиарейсы без потерь
# ## Система показателей эффективности выполнения авиаперевозок
# Для начала попытаемся определить метрики. Для этого была выбрана статья:
# ><i>Скипин Д.Л., Гущина А.С., Лобанова Э.В. Оценка эффективности выполнения авиаперевозок // Экономический анализ: теория и практика. 2018. №3 (474). URL: https://cyberleninka.ru/article/n/otsenka-effektivnosti-vypolneniya-aviaperevozok (дата обращения: 07.01.2021).</i>
#
# Приведем основные выдержки:
#
# В настоящее время в условиях высокой конкуренции на рынке авиаперевозок важно оперативно проводить оценку эффективности выполнения авиаперевозок, используя не только финансовые показатели, такие как <u>п р и б ы л ь , р е н т а б е л ь н о с т ь, но и производственные показатели деятельности</u>.
#
# Все эти данные, сформированные для целей управленческого учета, позволяют оценить себестоимость перевозки одного пассажира или одного килограмма груза в разрезе рейсов и воздушных судов, а также посчитать <u>доходность от одного перевезенного пассажира или одного килограмма груза</u>. При проведении анализа эффективности авиаперевозок объектом может служить <u>вся маршрутная сеть в целом, в разбивке по регионам, городам, по отдельным маршрутам или рейсам</u>. Анализируемый период при этом может варьироваться в зависимости от целей анализа.
#
# В табл. 1 представлена <u>система показателей эффективности выполнения авиаперевозок</u>.
#
# <img src="coef.png" alt="schema" width=700 height=500>

# %% [markdown]
# >**Показатели, характеризующие доходы:**
# >
# ><i><u>RASK и PRASK</u></i> - характеризуют сумму полученного дохода (совокупного и билетного соответственно) на
# анализируемом маршруте от максимально возможного количества кресел на воздушном судне в рассматриваемом периоде.
# >
# ><i><u>Yield и Yield (passenger revenue)</u></i> - удельный доход на 1 пассажиро-километр, для оценки суммы дохода (совокупного и билетного), полученного от одного перевезенного пассажира, соответственно. В отличие от RASK Yield характеризует объем полученного дохода от выполненного
# пассажирооборота.
# >
# >**Показатели, характеризующие расходы:**
# >
# ><i><u>CASK по совокупным и переменным расходам</u></i>. По аналогии с показателями RASK CASK характеризует сумму расходов (совокупных или переменных), приходящихся на один выполненный рейс по анализируемому маршруту или направлению.
# >
# >**Операционные показатели эффективности:**
# >
# ><i><u>Load Factor</u></i> - коэффициент коммерческой загрузки, показывает долю общего количества кресел, занятых пассажирами, и позволяет определить долю перевезенной коммерческой загрузки от максимально возможной [15]. Анализ динамики данного показателя позволяет варьировать воздушными судами в зависимости от пассажиропотока на различных маршрутах и тем самым оптимизировать себестоимость перевозки.
# >
# ><i><u>Величина среднего тарифа</u></i> рассчитывается как сумма билетного дохода, приходящаяся на одного пассажира. Иными словами, средний тариф характеризует среднюю цену билета на авиаперевозку на рассматриваемом маршруте.
# >
# >Операционные показатели эффективности рассматриваются в совокупности с показателями RASK и Yield, при этом они имеют тесную взаимосвязь друг с другом.
# >
# ><b>Оценка эффективности выполнения авиаперевозок:</b>
# >
# ><i><u>Суммы покрытия</u></i> - позволяют определить окупаемость каждой группы расходов, то есть на какой стадии производственный процесс не приносит прибыли или какие средства остаются в распоряжении предприятия после каждого этапа.
# >
# >Для этого рассчитывают показатели, характеризующие финансовый результат авиапредприятия (маржинальная прибыль по переменным расходам, по условно-переменным расходам и прибыль). Оценка эффективности на основе расчета маржинального дохода по переменным издержкам позволяет оценить, как выполнение конкретного рейса покрывает переменные издержки. Если сумма покрытия на рейсе является отрицательной, то руководство авиакомпании может принять решение о его закрытии. Эффект от такого управленческого решения наступает моментально, то есть убытки значительно сокращаются.
#
# Однако авторы статьи считают, что расчет показателей, характеризующих финансовый результат от выполненных авиаперевозок, целесообразно сравнивать и оценивать не в абсолютном, а <i><u>относительном выражении</u></i>. Расчет такого показателя приведен в табл. 2.
#
# <img src="coef2.png" alt="schema" width=700 height=500>

# %% [markdown]
# Итого:
#
# Доход на предельный пассажирооборот (PRASK) — отношение билетного дохода от авиаперевозок к предельному пассажирообороту. Используем PRASK вместо RASK, т.к. нет сведений о совокупных доходах.
#
# Затраты на предельный пассажирооборот (CASK) — отношение общих операционных затрат к предельному пассажирообороту.
#
# Предельный пассажирооборот (ASK) — мера измерения пассажирской провозной емкости, которой располагает авиакомпания,
# обозначает перемещение одного пассажирского кресла на расстояние один километр, измеряется в кресло-километрах (ккм)
#
# >https://www.rbc.ru/newspaper/2019/08/21/5d55445a9a7947a19f520c8c
#
# => RASK / CASK * 100%

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 50)
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
import datetime

# %% [markdown]
# <img src="sql-final-2.png" alt="schema" width=700 height=700>

# %%
# SELECT *
# FROM
#   (SELECT *
#    FROM dst_project.flights f
#    WHERE f.departure_airport = 'AAQ'
#      AND (date_trunc('month', f.scheduled_departure) in ('2017-01-01',
#                                                          '2017-02-01',
#                                                          '2017-12-01'))
#      AND f.status not in ('Cancelled')) a
# LEFT JOIN dst_project.ticket_flights tf ON a.flight_id = tf.flight_id
# LEFT JOIN dst_project.boarding_passes bp ON tf.flight_id = bp.flight_id
# AND tf.ticket_no = bp.ticket_no
# LEFT JOIN dst_project.aircrafts ac ON a.aircraft_code = ac.aircraft_code

df = pd.read_csv('3.csv').dropna(how='all', axis=1)

for col in ['scheduled_departure', 'scheduled_arrival', 'actual_departure', 'actual_arrival']:
    df[col] = pd.to_datetime(df[col], format='%Y-%m-%dT%H:%M:%SZ')

df['day'] = df['scheduled_departure'].dt.day
df['month'] = df['scheduled_departure'].dt.month
df['dep_date'] = df['scheduled_departure'].dt.strftime(date_format='%a %d.%m')
df['dow'] = df['scheduled_departure'].dt.strftime(date_format='%a')
df['woy'] = df['scheduled_departure'].dt.strftime(date_format='%W')

df.drop(['flight_id.1', 'ticket_no.1', 'flight_id.2', 'aircraft_code.2'], axis=1, inplace=True)

df['max_seats'] = df['aircraft_code'].apply(lambda x: 130 if x == '733' else 97)
df['distance'] = df['arrival_airport'].apply(lambda x: 1220 if x == 'SVO' else 639 if x == 'EGO' else 3662)
df['flight_time'] = (df['scheduled_arrival'] - df['scheduled_departure']).astype('timedelta64[m]')

df
# Out:
#        flight_id flight_no scheduled_departure   scheduled_arrival  \
# 0         136620    PG0480 2017-02-17 09:25:00 2017-02-17 10:15:00
# 1         136678    PG0480 2017-01-28 09:25:00 2017-01-28 10:15:00
# 2         136660    PG0480 2017-02-20 09:25:00 2017-02-20 10:15:00
# 3         136900    PG0480 2017-02-01 09:25:00 2017-02-01 10:15:00
# 4         136757    PG0480 2017-01-27 09:25:00 2017-01-27 10:15:00
# ...          ...       ...                 ...                 ...
# 11999     136544    PG0194 2017-01-31 06:10:00 2017-01-31 11:15:00
# 12000     136511    PG0194 2017-02-21 06:10:00 2017-02-21 11:15:00
# 12001     136540    PG0194 2017-01-17 06:10:00 2017-01-17 11:15:00
# 12002     136546    PG0194 2017-01-03 06:10:00 2017-01-03 11:15:00
# 12003     136567    PG0194 2017-02-14 06:10:00 2017-02-14 11:15:00
#
#       departure_airport arrival_airport   status aircraft_code  \
# 0                   AAQ             EGO  Arrived           SU9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12004 entries, 0 to 12003
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   flight_id            12004 non-null  int64
#  1   flight_no            12004 non-null  object
#  2   scheduled_departure  12004 non-null  datetime64[ns]
#  3   scheduled_arrival    12004 non-null  datetime64[ns]
#  4   departure_airport    12004 non-null  object
#  5   arrival_airport      12004 non-null  object
#  6   status               12004 non-null  object
#  7   aircraft_code        12004 non-null  object
#  8   actual_departure     12004 non-null  datetime64[ns]
#  9   actual_arrival       12004 non-null  datetime64[ns]
#  10  ticket_no            11995 non-null  float64
#  11  fare_conditions      11995 non-null  object
#  12  amount               11995 non-null  float64
#  13  boarding_no          11995 non-null  float64
# ...

# %%
# предгруппировка:
df.groupby(by=[
    'flight_no', 'aircraft_code', 'arrival_airport', 'flight_id', 'scheduled_departure',
    'dep_date', 'dow', 'woy', 'distance', 'flight_time'
#     , 'fare_conditions'
    ]).agg(pas=('seat_no', 'count'), revenue=('amount', 'sum'))
# Out:
#                                                                                                               pas  \
# flight_no aircraft_code arrival_airport flight_id scheduled_departure dep_date  dow woy distance flight_time
# PG0194    733           NOZ             136511    2017-02-21 06:10:00 Tue 21.02 Tue 08  3662     305.0          0
#                                         136513    2017-02-28 06:10:00 Tue 28.02 Tue 09  3662     305.0          0
#                                         136514    2017-02-07 06:10:00 Tue 07.02 Tue 06  3662     305.0          0
#                                         136523    2017-01-10 06:10:00 Tue 10.01 Tue 02  3662     305.0          0
#                                         136540    2017-01-17 06:10:00 Tue 17.01 Tue 03  3662     305.0          0
# ...                                                                                                           ...
# ...

# %%
# итоговый датасет для анализа рейсов. Группировку выполнили здесь. Код для получения сразу из ДБ:

# SELECT a.flight_no,
#        a.aircraft_code,
#        a.arrival_airport,
#        a.flight_id,
#        a.scheduled_departure,
#        count(DISTINCT bp.seat_no) pas,
#        sum(tf.amount) revenue
# FROM
#   (SELECT *
#    FROM dst_project.flights f
#    WHERE f.departure_airport = 'AAQ'
#      AND (date_trunc('month', f.scheduled_departure) in ('2017-01-01',
#                                                          '2017-02-01',
#                                                          '2017-12-01'))
#      AND f.status not in ('Cancelled')) a
# LEFT JOIN dst_project.ticket_flights tf ON a.flight_id = tf.flight_id
# LEFT JOIN dst_project.boarding_passes bp ON tf.flight_id = bp.flight_id
# AND tf.ticket_no = bp.ticket_no
# GROUP BY 1,
#          2,
#          3,
#          4,
#          5
# ORDER BY 5;

fl = pd.DataFrame(df.groupby(by=[
    'flight_no', 'aircraft_code', 'model', 'arrival_airport', 'flight_id', 'scheduled_departure',
    'dep_date', 'dow', 'woy', 'max_seats', 'distance', 'flight_time'
     ]).agg(pas=('seat_no', 'count'), revenue=('amount', 'sum'))   # revenue = ДБ (доход билетный)
     ).sort_values('scheduled_departure').reset_index()

fl['load_factor'] = fl['pas'] / fl['max_seats']
fl['ASK'] = fl['max_seats'] * fl['distance']
fl['PRASK'] = fl['revenue'] / fl['ASK']
fl['yield'] = fl['PRASK'] / fl['load_factor']   # Yield (PR) = revenue / PK (Passenger-kilometer, ДБ / ПКМ) = 
                                                # RASK / load_factor
fl['CASK'] = fl['aircraft_code'].apply(lambda x: 15.75 if x == 'SU9' else 9)   # в статье от 2019 7 и 4, взяли *2.25
                                            # для заполнения специалистами, здесь даные внесли для чернового анализа
fl['coef'] = fl['PRASK'] / fl['CASK'] * 100
fl
# Out:
#     flight_no aircraft_code                model arrival_airport  flight_id  \
# 0      PG0480           SU9  Sukhoi Superjet-100             EGO     136661
# 1      PG0252           733       Boeing 737-300             SVO     136420
# 2      PG0480           SU9  Sukhoi Superjet-100             EGO     136936
# 3      PG0252           733       Boeing 737-300             SVO     136458
# 4      PG0194           733       Boeing 737-300             NOZ     136546
# ..        ...           ...                  ...             ...        ...
# 122    PG0480           SU9  Sukhoi Superjet-100             EGO     136953
# 123    PG0252           733       Boeing 737-300             SVO     136266
# 124    PG0194           733       Boeing 737-300             NOZ     136513
# 125    PG0480           SU9  Sukhoi Superjet-100             EGO     136844
# 126    PG0252           733       Boeing 737-300             SVO     136215
#
# ...

# %%
fl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   flight_no            127 non-null    object
#  1   aircraft_code        127 non-null    object
#  2   model                127 non-null    object
#  3   arrival_airport      127 non-null    object
#  4   flight_id            127 non-null    int64
#  5   scheduled_departure  127 non-null    datetime64[ns]
#  6   dep_date             127 non-null    object
#  7   dow                  127 non-null    object
#  8   woy                  127 non-null    object
#  9   max_seats            127 non-null    int64
#  10  distance             127 non-null    int64
#  11  flight_time          127 non-null    float64
#  12  pas                  127 non-null    int64
#  13  revenue              127 non-null    float64
#  14  load_factor          127 non-null    float64
# ...

# %%
sns.boxplot(data=fl, x='arrival_airport', y='coef', hue='model')
# Out:
# <AxesSubplot:xlabel='arrival_airport', ylabel='coef'>

# %%
fl[(fl['arrival_airport'] == 'SVO') & (fl['coef'] < 100)]
# Out:
#    flight_no aircraft_code           model arrival_airport  flight_id  \
# 18    PG0252           733  Boeing 737-300             SVO     136464
# 83    PG0252           733  Boeing 737-300             SVO     136250
#
#    scheduled_departure   dep_date  dow woy  max_seats  distance  flight_time  \
# 18 2017-01-09 10:05:00  Mon 09.01  Mon  02        130      1220        100.0
# 83 2017-02-08 10:05:00  Wed 08.02  Wed  06        130      1220        100.0
#
#     pas    revenue  load_factor     ASK     PRASK      yield  CASK       coef
# 18  100  1398000.0     0.769231  158600  8.814628  11.459016   9.0  97.940311
# 83   99  1407800.0     0.761538  158600  8.876419  11.655903   9.0  98.626874

# %% [markdown]
# Предв вывод: SU9 убыточен в принципе из-за малой пассажироемкости и высоких операционных расходов. Предложение: заменить на Боинг на рейсе в Белгород и сократить количество рейсов в дни с малым пассажиропотоком.

# %% [markdown]
# # EDA

# %%
df[df['arrival_airport'] == 'NOZ']
# Out:
#        flight_id flight_no scheduled_departure   scheduled_arrival  \
# 11995     136523    PG0194 2017-01-10 06:10:00 2017-01-10 11:15:00
# 11996     136513    PG0194 2017-02-28 06:10:00 2017-02-28 11:15:00
# 11997     136514    PG0194 2017-02-07 06:10:00 2017-02-07 11:15:00
# 11998     136560    PG0194 2017-01-24 06:10:00 2017-01-24 11:15:00
# 11999     136544    PG0194 2017-01-31 06:10:00 2017-01-31 11:15:00
# 12000     136511    PG0194 2017-02-21 06:10:00 2017-02-21 11:15:00
# 12001     136540    PG0194 2017-01-17 06:10:00 2017-01-17 11:15:00
# 12002     136546    PG0194 2017-01-03 06:10:00 2017-01-03 11:15:00
# 12003     136567    PG0194 2017-02-14 06:10:00 2017-02-14 11:15:00
#
#       departure_airport arrival_airport   status aircraft_code  \
# 11995               AAQ             NOZ  Arrived           733
# 11996               AAQ             NOZ  Arrived           733
# 11997               AAQ             NOZ  Arrived           733
# ...

# %%
fig, axes = plt.subplots(2, 1, sharex=True, figsize=(16,12))
# fig.suptitle('Passenger rate')

# исключаем NOZ, тк данных о пассажирах по этим рейсам нет
sns.barplot(ax=axes[0], data=fl[fl['arrival_airport'] != 'NOZ'], x='dep_date', y='pas', hue='arrival_airport')
axes[0].set_title('General passenger rate by cities')
axes[0].tick_params(labelrotation=45)

xs = np.linspace(-0.5,58.5,58)
const130 = np.array([130 for i in range(len(xs))])
const97 = np.array([97 for i in range(len(xs))])
axes[0].plot(xs, const130, color='grey', linestyle='solid')
axes[0].plot(xs, const97, color='grey', linestyle='solid')

sns.barplot(ax=axes[1], data=fl[fl['arrival_airport'] != 'NOZ'], x='dep_date', y='load_factor', hue='model')
axes[1].set_title('Passenger flight occupancy by aircrafts')
axes[1].tick_params(labelrotation=45)

const75 = np.array([0.75 for i in range(len(xs))])
axes[1].plot(xs, const75, 'g-')

plt.show()

# %% [markdown]
# Рейсы в Новокузнецк каждую неделю, Боинг, однако нет данных о пассажирах - нельзя судить о заполняемости.

# %%
fig, axes = plt.subplots(2, 1, figsize=(9, 12))

sns.boxplot(ax=axes[0], data=fl[fl['arrival_airport'] != 'NOZ'], x='dow', y='pas', hue='arrival_airport')
axes[0].set_title('Genral passenger rate by cities over the week')

sns.boxplot(ax=axes[1], data=fl[fl['arrival_airport'] != 'NOZ'], x='dow', y='load_factor', hue='model')
axes[1].set_title('Passenger flight occupancy over the week')

plt.show()

# %% [markdown]
# Общий пассажиропоток:
# - На рейсах в Белгород - провалы как правило в периоды вс-вт.
# - На рейсах в Москву - неупорядоченные пики; во вторник всегда высокий пассажиропоток.

# %% [markdown]
# Заполняемость рейсов:
# - SU9, как правило, более заполнен, чем Боинг.
# - В середине недели (ср-сб) SU9 чаще всего заполнен на уровне 87-100%, в ср почти всегда заполнен полностью, спад заполняемости в вс-пн.
# - В целом в теч недели заполняемость выше уровня рентабельности (75%).
# - Наибольший разброс - в пн (бывает ниже рентабельности).
#
#
# - В общем на высоком уровне и с наименьшим разбросом Боинг заполнен по вторникам (от 82 до 98%),
#
# В то же время общий пассажиропоток в Москву выше, чем в Белгород (см выше), поэтому выбор Боинга на этом направлении может быть оправдан. Необходимо сравнить издержки и подумать о замене судна/-ен на данных рейсах + сокращение полетов в опред дни.

# %% [markdown]
# # Анализ показателей эффективности

# %%
fl
# Out:
#     flight_no aircraft_code                model arrival_airport  flight_id  \
# 0      PG0480           SU9  Sukhoi Superjet-100             EGO     136661
# 1      PG0252           733       Boeing 737-300             SVO     136420
# 2      PG0480           SU9  Sukhoi Superjet-100             EGO     136936
# 3      PG0252           733       Boeing 737-300             SVO     136458
# 4      PG0194           733       Boeing 737-300             NOZ     136546
# ..        ...           ...                  ...             ...        ...
# 122    PG0480           SU9  Sukhoi Superjet-100             EGO     136953
# 123    PG0252           733       Boeing 737-300             SVO     136266
# 124    PG0194           733       Boeing 737-300             NOZ     136513
# 125    PG0480           SU9  Sukhoi Superjet-100             EGO     136844
# 126    PG0252           733       Boeing 737-300             SVO     136215
#
# ...

# %% [markdown]
# Т.к. принимается решение о закрытии рейсов в определенные дни недели, будем рассматривать рейсы по направлениям в разрезе дней недели.

# %%
fig, axes = plt.subplots(2, 2, figsize=(15,12))
fig.suptitle('Efficiency coefficients analysis')

sns.boxplot(ax=axes[0,0], data=fl[fl['arrival_airport'] != 'NOZ'], x='dow', y='PRASK', hue='arrival_airport')
axes[0,0].set_title('PRASK')

sns.boxplot(ax=axes[0,1], data=fl[fl['arrival_airport'] != 'NOZ'], x='dow', y='CASK', hue='arrival_airport')
axes[0,1].set_title('CASK')

sns.boxplot(ax=axes[1,0], data=fl[fl['arrival_airport'] != 'NOZ'], x='dow', y='yield', hue='arrival_airport')
axes[1,0].set_title('Yield')

sns.boxplot(ax=axes[1,1], data=fl[fl['arrival_airport'] != 'NOZ'], x='dow', y='coef', hue='arrival_airport')
axes[1,1].set_title('PRASK/CASK')
# Out:
# Text(0.5, 1.0, 'PRASK/CASK')
